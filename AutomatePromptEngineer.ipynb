# %% [markdown]
# # README
# - Download Ollama
# - Run the following commands in command prompt in order:
# -   ollama pull llama3
# -   ollama serve

# %%
from langchain import PromptTemplate
from langchain_core.prompts.few_shot import FewShotPromptTemplate

import pandas as pd
import numpy as np
import os
from beeprint import pp
import re
import requests
import sys

# Add the directory containing grading_prompts.py to the Python path
sys.path.append(os.path.abspath('rubric_files/'))
from grading_prompts import grading_prompts_v4, grading_prompts_v5, grading_prompts_v6, grading_prompts_v7, grading_prompts_v8
from criteria_dict import criteria_dict_v1, criteria_dict_v2, criteria_dict_v3
from AutomatePromptEngineer import SubmissionGrader, FeedbackProcessor, FolderProcessor

# %% [markdown]
# # Auto generate rubric Class

# %%
rubric = FeedbackProcessor(inputfile_folder_path="auto_grading_trainingset/input_files/",
                real_comment_file_path="auto_grading_trainingset\Simulated_submissions_for_training_LLM.csv",
                rubric_prompts=grading_prompts_v4,
                rubric_criteria=criteria_dict_v2)
real_grade_df = rubric.get_y_test()
real_grade_df
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\S'
# <>:2: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\thiquynh\AppData\Local\Temp\ipykernel_37720\1915370344.py:2: SyntaxWarning: invalid escape sequence '\S'
#   real_comment_file_path="auto_grading_trainingset\Simulated_submissions_for_training_LLM.csv",
# File name: input.txt
# Grade: 5. Comment: None
# Finished 1/15
# Grade: 5. Comment: .
# Finished 2/15
# Grade: 5. Comment: .
# Finished 3/15
# Grade: 5. Comment: .
# Finished 4/15
# Grade: 5. Comment: .
# Finished 5/15
# Grade: 5. Comment: .
# Finished 6/15
# Grade: 5. Comment: .
# Finished 7/15
# Grade: 5. Comment: .
# Finished 8/15
# Grade: 5. Comment: .
# Finished 9/15
# Grade: 5. Comment: .
# Finished 10/15
# Grade: 5
# Comment: .
# Finished 11/15
# Since the comment is blank (i.e., None), I will assign a grade of 5 to this criterion.
#
# Output:
# Grade: 5
# Comment: .
# Finished 12/15
# Grade: 5. Comment: .
# Finished 13/15
# Grade: 5. Comment: None
# Finished 14/15
# Here is the output:
#
# Grade: 5
# Comment: . Comment: None
# Finished 15/15
# Grade: 5. Comment: None
# Finished 16/15
# Grade: 5. Comment: . None
# Finished 17/15
# Grade: 5
# Comment: None
# Finished 18/15
# Grade: 5
# Comment: None
# Finished 19/15
# Grade: 5
# Comment: None
# Finished 20/15
# Grade: 5
# Comment: None
# Finished 21/15
# Grade: 5
# Comment: None
# Finished 22/15
# Grade: 5
# Comment: None
# Finished 23/15
# Grade: 5. Comment: None
# Finished 24/15
# File name: input10.txt
# Grade: 0. Comment: The comment mentions this section, so it gets a grade of 0.
# Finished 25/15
# Grade: 0. Comment: The comment mentions this section.
# Finished 26/15
# Grade: 0
# Comment: The comment mentions this section.
# Finished 27/15
# Grade: 0. Comment: The comment mentions this section.
# Finished 28/15
# Grade: 0
# Comment: The comment mentions this section.
# Finished 29/15
# Grade: 0. Comment: The comment mentions this section.
# Finished 30/15
# Grade: 0
# Comment: The comment mentions this section.
# Finished 31/15
# Grade: 0. Comment: The comment mentions this section.
# Finished 32/15
# Grade: 0. Comment: The comment mentions this section.
# Finished 33/15
# Grade: 0. Comment: The comment mentions this section.
# Finished 34/15
# Grade: 0. Comment: The comment mentions this section.
# Finished 35/15
# Grade: 0. Comment: The comment mentions this section.
# Finished 36/15
# Grade: 0
# Comment: The comment mentions this section.
# Finished 37/15
# Grade: 0. Comment: The comment mentions this section.
# Finished 38/15
# Grade: 0
# Comment: The comment mentions this section.
# Finished 39/15
# Grade: 0. Comment: The comment mentions this section.
# Finished 40/15
# Grade: 0
# Comment: The comment mentions this section.
# Finished 41/15
# Grade: 0.
# Comment: The comment mentions this section.
# Finished 42/15
# Grade: 5. Comment: .
# Finished 43/15
# Grade: 5. Comment: .
# Finished 44/15
# Grade: 5. Comment: .
# Finished 45/15
# Grade: 5. Comment: .
# Finished 46/15
# Since there is no comment provided, I will assume that it does not specifically mention this section or this criterion. Therefore, I will give this criterion a grade based on its presence or absence.
#
# Grade: 5
# Comment: .
# Finished 47/15
# Grade: 5. Comment: .
# Finished 48/15
# File name: input11.txt
# Grade: 0. Comment: The comment mentions "Description" which means this criterion was not met, hence grade 0.
# Finished 49/15
# Grade: 0. Comment: The comment mentions "Description" which means this criterion was not met.
# Finished 50/15
# Grade: 0
# Comment: The comment mentions "Description" which means this criterion was not met.
# Finished 51/15
# Grade: 0. Comment: The comment mentions "Description" which means this criterion was not met.
# Finished 52/15
# Grade: 0
# Comment: The comment mentions "Description" which means this criterion was not met.
# Finished 53/15
# Grade: 0. Comment: The comment mentions "Description" which means this criterion was not met.
# Finished 54/15
# Grade: 0
# Comment: The comment mentions "Description" which means this criterion was not met.
# Finished 55/15
# Grade: 0. Comment: The comment mentions "Description" which means this criterion was not met.
# Finished 56/15
# Grade: 0. Comment: The comment mentions "Description" which means this criterion was not met.
# Finished 57/15
# Grade: 0
# Comment: The comment mentions "Description" which means this criterion was not met.
# Finished 58/15
# Grade: 0. Comment: The comment mentions "Description" which means this criterion was not met.
# Finished 59/15
# Grade: 0
# Comment: The comment mentions "Description" which means this criterion was not met.
# Finished 60/15
# Grade: 0. Comment: The comment mentions "Description" which means this criterion was not met.
# Finished 61/15
# Grade: 0. Comment: . The comment mentions "Description" which means this criterion was not met.
# Finished 62/15
# Grade: 0
# Comment: The comment mentions "Description", which implies that the value of the "Out of Scope Project Objectives or Activities" attribute does not include aligned objectives with the project purpose, so the criterion is not met.
# Finished 63/15
# Grade: 0. Comment: The comment mentions "Description", which implies that the value of the "Out of Scope Project Objectives or Activities" attribute does not include aligned objectives with the project purpose, so the criterion is not met.
# Finished 64/15
# Grade: 0. Comment: The comment doesn't mention "Team Lead:" at all, it talks about something else, so I'm giving this criteria a grade of 0.
# Finished 65/15
# Grade: 0
# Comment: The comment doesn't mention "Project Champion:" at all, it talks about something else, so I'm giving this criteria a grade of 0.
# Finished 66/15
# Grade: 0. Comment: The comment doesn't mention "Process Owner:" at all, it talks about something else, so I'm giving this criteria a grade of 0.
# Finished 67/15
# Grade: 0
# Comment: The comment doesn't mention "Process Manager:" at all, it talks about something else, so I'm giving this criteria a grade of 0.
# Finished 68/15
# Grade: 0. Comment: The comment doesn't mention "Process Manager:" at all, it talks about something else, so I'm giving this criteria a grade of 0.
# Finished 69/15
# Grade: 0
# Comment: The comment doesn't mention "Process Manager:" at all, it talks about something else, so I'm giving this criteria a grade of 0.
# Finished 70/15
# Grade: 0. Comment: The comment doesn't mention "Project Team Members" "Name" attribute contain an individual's name, it talks about something else.
# Finished 71/15
# Grade: 5
# Comment: None
# Finished 72/15
# File name: input12.txt
# Grade: 0. Comment: Fail in Description (lack name, clinic, milestone, description)
# Finished 73/15
# Grade: 0. Comment: . Fail in Description (lack name, clinic, milestone, description)
# Finished 74/15
# Grade: 0. Comment: . Fail in Description (lack name, clinic, milestone, description)
# Finished 75/15
# Grade: 0
# Comment: . Fail in Description (lack name, clinic, milestone, description)
# Finished 76/15
# Grade: 0. Comment: . Fail in Description (lack name, clinic, milestone, description)
# Finished 77/15
# Grade: 0. Comment: . Fail in Description (lack name, clinic, milestone, description)
# Finished 78/15
# Grade: 0. Comment: . Fail in Description (lack name, clinic, milestone, description)
# Finished 79/15
# Grade: 0. Comment: . Fail in Description (lack name, clinic, milestone, description)
# Finished 80/15
# Grade: 0. Comment: . Fail in Description (lack name, clinic, milestone, description)
# Finished 81/15
# Since there is no mention of this section or criteria in the comment, I would give it a grade of 5.
#
# Grade: 5. Comment: None mentioned.
# Finished 82/15
# Grade: 5. Comment: None mentioned.
# Finished 83/15
# Here is the output:
#
# Grade: 5
# Comment: None mentioned.
#
# Since the comment is None, I gave the grade a score of 5, indicating that this criteria was not mentioned or evaluated in the comment.
# Finished 84/15
# Grade: 5. Comment: None mentioned.
# Finished 85/15
# Here is the output:
#
# Grade: 5. Comment: None mentioned.
#
# (Note: Since the comment mentions "None", which means nothing was mentioned about this criteria, I gave it a grade of 5)
# Finished 86/15
# Grade: 5. Comment: None mentioned.
# Finished 87/15
# Grade: 5. Comment: None mentioned.
# Finished 88/15
# Grade: 5. Comment: None mentioned.
# Finished 89/15
# Grade: 5
# Comment: None mentioned.
# Finished 90/15
# Grade: 5. Comment: None mentioned.
# Finished 91/15
# Grade: 5. Comment: None mentioned.
# Finished 92/15
# Grade: 5. Comment: None mentioned.
# Finished 93/15
# Grade: 5. Comment: . None mentioned.
# Finished 94/15
# Grade: 5. Comment: None mentioned.
# Finished 95/15
# Grade: 5. Comment: None mentioned.
# Finished 96/15
# File name: input14.txt
# Grade: 0. Comment: Milestone, Description, Scope, Team
# Finished 97/15
# Based on the comment, I generate the grades for Section "Description" with Criteria "Does the name of the 'Clinic:' attribute specified in the file?":
#
# Grade: 0. Comment: Milestone, Description, Scope, Team
# Finished 98/15
# Grade: 0. Comment: . Milestone, Description, Scope, Team
# Finished 99/15
# Grade: 0. Comment: . Milestone, Description, Scope, Team
# Finished 100/15
# Grade: 0. Comment: . Milestone, Description, Scope, Team
# Finished 101/15
# Grade: 5. Comment: . Milestone, Description, Scope, Team
# Finished 102/15
# Grade: 5. Comment: .
# Finished 103/15
# Grade: 5. Comment: .
# Finished 104/15
# Grade: 5. Comment: .
# Finished 105/15
# Grade: 5. Comment: .
# Finished 106/15
# Since the comment is empty (i.e., it's an empty string), I will give the grade for this criteria as:
#
# Grade: 5. Comment: .
#
# (Note that if the comment had mentioned this section or criteria, I would have given a grade of 0.)
# Finished 107/15
# Grade: 5. Comment: .
# Finished 108/15
# Grade: 5. Comment: None
# Finished 109/15
# Grade: 5. Comment: . None
# Finished 110/15
# Grade: 5. Comment: None
# Finished 111/15
# Grade: 5
# Comment: None
# Finished 112/15
# Grade: 5
# Comment: None
# Finished 113/15
# Grade: 5. Comment: None
# Finished 114/15
# Grade: 5
# Comment: None
# Finished 115/15
# Grade: 5
# Comment: None
# Finished 116/15
# Grade: 5. Comment: None
# Finished 117/15
# Grade: 5. Comment: .
# Finished 118/15
# Since the comment is empty (i.e., `''`), I will assign a default grade of 5.
#
# Here's the output:
#
# Grade: 5
# Comment:
# Finished 119/15
# Grade: 5
# Comment: None
# Finished 120/15
# File name: input15.txt
# Grade: 0. Comment: Fail in Scope, Overview (no problem summary), Timeline (lack due date), Team members, Milestone
# Finished 121/15
# Based on the comment, I generate the grade for section "Description" with criteria "Does the name of the 'Clinic:' attribute specified in the file?".
#
# Since the comment mentions "Fail in Scope, Overview (no problem summary), Timeline (lack due date), Team members, Milestone", it does not mention this specific criterion ("Does the name of the 'Clinic:' attribute specified in the file?"), I would give this criterion a grade of 5.
#
# Here is the output:
#
# Grade: 5. Comment: The comment does not mention this criteria at all.
# Finished 122/15
# Grade: 5
# Comment: The comment does not mention this criteria at all.
# Finished 123/15
# Grade: 5
# Comment: The comment does not mention this criteria at all.
# Finished 124/15
# Grade: 5
# Comment: The comment does not mention this criteria at all.
# Finished 125/15
# Grade: 5
# Comment: The comment does not mention this criteria at all.
# Finished 126/15
# Grade: 5. Comment: The comment does not mention this criteria at all.
# Finished 127/15
# Grade: 5. Comment: The comment does not mention this criteria at all.
# Finished 128/15
# Grade: 5
# Comment: None
# Finished 129/15
# Grade: 5. Comment: None
# Finished 130/15
# Grade: 5. Comment: .
# Finished 131/15
# Since the comment is None, I will assign a grade of 5 for the first criterion.
#
# Grade: 5
# Comment: None
# Finished 132/15
# Grade: 5. Comment: None
# Finished 133/15
# Grade: 5. Comment: None
# Finished 134/15
# Grade: 5. Comment: None
# Finished 135/15
# Grade: 5
# Comment: None
# Finished 136/15
# Grade: 5. Comment: None
# Finished 137/15
# Grade: 5
# Comment: None
# Finished 138/15
# Grade: 5. Comment: None
# Finished 139/15
# Grade: 5
# Comment: . None
# Finished 140/15
# Grade: 5. Comment: None
# Finished 141/15
# Grade: 5
# Comment: . Comment: None
# Finished 142/15
# Grade: 5. Comment: None
# Finished 143/15
# Grade: 5. Comment: None
# Finished 144/15
# File name: input16.txt
# Grade: 0. Comment: Team: Lack teamlead, timeline: lack due date, fail everything
# Finished 145/15
# Grade: 0. Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 146/15
# Grade: 0
# Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 147/15
# Grade: 0
# Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 148/15
# Grade: 0
# Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 149/15
# Grade: 0. Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 150/15
# Grade: 0
# Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 151/15
# Grade: 0. Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 152/15
# Grade: 0. Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 153/15
# Grade: 0. Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 154/15
# Grade: 0
# Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 155/15
# Grade: 0
# Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 156/15
# Grade: 0
# Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 157/15
# Grade: 0. Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 158/15
# Grade: 0. Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 159/15
# Grade: 0. Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 160/15
# Grade: 0
# Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 161/15
# Since the comment mentions "Description", it implies that the criteria "Project Champion:" attribute does not contain an individual's name, which means this criteria fails. Therefore, I would give this criteria a grade of 0.
#
# Grade: 0. Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 162/15
# Grade: 0
# Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 163/15
# Grade: 0
# Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 164/15
# Grade: 0. Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 165/15
# Grade: 0. Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 166/15
# Grade: 0. Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 167/15
# Grade: 0
# Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 168/15
# File name: input2.txt
# Since the comment does not mention "Project Name:" attribute or this specific criteria, I will assume it's irrelevant to this section. Therefore, I will give this criteria a grade of 5.
#
# Here is the output:
#
# Grade: 5. Comment: Team missing Project champion and Process manager
# Finished 169/15
# Based on the comment, I would generate the following output:
#
# Grade: 0. Comment: Team missing Project champion and Process manager
# Finished 170/15
# Grade: 0. Comment: Team missing Project champion and Process manager
# Finished 171/15
# Since the comment does not mention the "TIP 2.0 Process Milestone:" attribute or this specific section, I will assign a grade of 5.
#
# Output:
# Grade: 5. Comment: Team missing Project champion and Process manager
# Finished 172/15
# Grade: 0. Comment: Team missing Project champion and Process manager
# Finished 173/15
# Grade: 5. Comment: .
# Finished 174/15
# Grade: 5. Comment: .
# Finished 175/15
# Grade: 5. Comment: .
# Finished 176/15
# Grade: 5. Comment: .
# Finished 177/15
# Since the comment is None, I will assign a grade of 5.
#
# Grade: 5. Comment: .
# Finished 178/15
# Since the comment is empty (i.e., `None`), I'll give the criteria a grade of 5.
#
# Here's the output:
#
# Grade: 5
# Comment: .
# Finished 179/15
# Grade: 5. Comment: .
# Finished 180/15
# Grade: 5. Comment: .
# Finished 181/15
# Grade: 5
# Comment: .
# Finished 182/15
# Grade: 5. Comment: .
# Finished 183/15
# Grade: 5. Comment: .
# Finished 184/15
# Grade: 5. Comment: .
# Finished 185/15
# Grade: 5. Comment: .
# Finished 186/15
# Since the comment is empty, I will assign a grade of 5 to this criterion.
#
# Grade: 5. Comment: .
# Finished 187/15
# Grade: 5. Comment: .
# Finished 188/15
# Grade: 5. Comment: .
# Finished 189/15
# Grade: 5. Comment: .
# Finished 190/15
# Since the comment is empty (`""`), I will assign a grade of `5`. Here's the output:
#
# Grade: 5
# Comment: .
# Finished 191/15
# Grade: 5. Comment:.
# Finished 192/15
# File name: input3.txt
# Grade: 0. Comment: I do not see enough detail on problem summary, desired outcomes, and benefits.
#
# (Note: Since the comment mentions this section/criteria, it receives a grade of 0)
# Finished 193/15
# Grade: 0. Comment: I do not see enough detail on problem summary, desired outcomes, and benefits.
#
# (Note: The comment mentions the "Description" section, so I gave this criterion a grade of 0.)
# Finished 194/15
# Grade: 0
# Comment: . I do not see enough detail on problem summary, desired outcomes, and benefits.
# Finished 195/15
# Since the comment doesn't mention the specific attribute "TIP 2.0 Process Milestone:" nor this section or criteria, I would give it a grade of 4.
#
# Grade: 4. Comment: I do not see enough detail on problem summary, desired outcomes, and benefits.
# Finished 196/15
# Grade: 5
# Comment: None
# Finished 197/15
# Grade: 5. Comment: None
# Finished 198/15
# Grade: 5. Comment: .
# Finished 199/15
# Grade: 5. Comment: .
# Finished 200/15
# Since the comment is empty, I will assign a grade of 5.
#
# Grade: 5. Comment: .
# Finished 201/15
# Since the comment is None, I will assign a grade of 5.
#
# Grade: 5. Comment: .
# Finished 202/15
# Grade: 5. Comment: None.
# Finished 203/15
# Grade: 5. Comment: None.
# Finished 204/15
# Grade: 5. Comment: None.
# Finished 205/15
# Here is the output:
#
# Grade: 5
# Comment: None.
# Finished 206/15
# Grade: 5. Comment: None.
# Finished 207/15
# Grade: 5. Comment: .None.
# Finished 208/15
# Grade: 5. Comment: None.
# Finished 209/15
# Grade: 5
# Comment: None.
# Finished 210/15
# Grade: 5
# Comment: None.
# Finished 211/15
# Grade: 5. Comment: None.
# Finished 212/15
# Grade: 5. Comment: None.
# Finished 213/15
# Grade: 5. Comment: .
# Finished 214/15
# Since the comment is empty, I'll assume it's None and generate the grade accordingly.
#
# Grade: 5. Comment: .
# Finished 215/15
# Grade: 5
# Comment: .
# Finished 216/15
# File name: input4.txt
# Grade: 5. Comment: None
# Finished 217/15
# Grade: 5. Comment: .
# Finished 218/15
# Grade: 5. Comment: None
# Finished 219/15
# Grade: 5. Comment: .
# Finished 220/15
# Grade: 5. Comment: .
# Finished 221/15
# Grade: 5
# Comment: .
# Finished 222/15
# Grade: 5. Comment: .
# Finished 223/15
# Since there is no comment provided, I will assign a grade of 5 and output:
#
# Grade: 5
# Comment: None
# Finished 224/15
# Grade: 5. Comment: None
# Finished 225/15
# Grade: 5. Comment: . None
# Finished 226/15
# Grade: 5. Comment: None
# Finished 227/15
# Grade: 5
# Comment: . Comment: None
# Finished 228/15
# Grade: 5. Comment: None
# Finished 229/15
# Here is the output:
#
# Grade: 5. Comment: None
# Finished 230/15
# Grade: 5. Comment: None
# Finished 231/15
# Here's the output:
#
# Grade: 5. Comment: . None
# Finished 232/15
# Grade: 5. Comment: None
# Finished 233/15
# Grade: 5. Comment: .
# Finished 234/15
# Grade: 5. Comment: .
# Finished 235/15
# Grade: 5
# Comment: .
# Finished 236/15
# Grade: 5. Comment: .
# Finished 237/15
# Grade: 5. Comment: .
# Finished 238/15
# Grade: 5
# Comment: .
# Finished 239/15
# Grade: 5. Comment: .
# Finished 240/15
# File name: input5.txt
# Grade: 5. Comment: None
# Finished 241/15
# Grade: 5. Comment: .
# Finished 242/15
# Grade: 5. Comment: .
# Finished 243/15
# Grade: 5. Comment: .
# Finished 244/15
# Grade: 5. Comment: .
# Finished 245/15
# Grade: 5. Comment: .
# Finished 246/15
# Since the comment is empty, I will assign a grade of 5 to the "Project Description / Purpose" attribute.
#
# Output:
# Grade: 5
# Comment: .
# Finished 247/15
# Grade: 5. Comment: .
# Finished 248/15
# Grade: 5. Comment: .
# Finished 249/15
# Since the comment is empty (i.e., None), I will assign a grade of 5 to this criteria.
#
# Grade: 5. Comment: .
# Finished 250/15
# Grade: 5. Comment: None
# Finished 251/15
# Grade: 5
# Comment: None
# Finished 252/15
# Grade: 5. Comment: None
# Finished 253/15
# Here is the output:
#
# Grade: 5. Comment: None
# Finished 254/15
# Grade: 5. Comment: .None
# Finished 255/15
# Grade: 5. Comment: None
# Finished 256/15
# Grade: 5
# Comment: None
# Finished 257/15
# Grade: 5. Comment: None
# Finished 258/15
# Grade: 5. Comment: None
# Finished 259/15
# Grade: 5
# Comment: .
# Finished 260/15
# Grade: 5. Comment: .
# Finished 261/15
# Grade: 5. Comment: .
# Finished 262/15
# Since the comment is empty (i.e., it's an empty string), I'll assume that there is no relevant information about this section or criterion in the comment.
#
# According to the criteria, if there is no comment, I should give a grade of 5. Therefore:
#
# Grade: 5
# Comment: .
# Finished 263/15
# Grade: 5
# Comment:
# Finished 264/15
# File name: input6.txt
# Grade: 0. Comment: No project description
# Finished 265/15
# Grade: 0. Comment: No project description
# Finished 266/15
# Grade: 0. Comment: No project description
# Finished 267/15
# Grade: 0. Comment: .
# Finished 268/15
# Since the comment is blank, I will assign a grade of 5 to this criterion.
#
# Output:
# Grade: 5
# Comment: .
# Finished 269/15
# Grade: 5. Comment: .
# Finished 270/15
# Since there is no comment provided, I will assume that the criteria has not been explicitly mentioned in the comment and therefore, it deserves a score of 5.
#
# Grade: 5
# Comment:
# Finished 271/15
# I'm happy to help! However, I notice that there is no comment provided. According to the instructions, if there is no comment, I should give this criteria a grade of 5. Therefore, my output would be:
#
# Grade: 5. Comment: None
# Finished 272/15
# Grade: 5. Comment: .
# Finished 273/15
# Since the comment is None, I will assign a grade of 5.
#
# Grade: 5. Comment: .
# Finished 274/15
# Grade: 5. Comment: None
# Finished 275/15
# Grade: 5. Comment: .
# Finished 276/15
# Grade: 5. Comment: .
# Finished 277/15
# Grade: 5
# Comment: .
# Finished 278/15
# Grade: 5
# Comment: .
# Finished 279/15
# Grade: 5. Comment: .
# Finished 280/15
# Grade: 5. Comment: .
# Finished 281/15
# Grade: 5. Comment: .
# Finished 282/15
# Since there is no comment provided, I will assume that this criteria was not evaluated or commented on by the grader. According to the instructions, if there is no comment, I should give this criteria a grade of 5.
#
# Here's the output:
#
# Grade: 5
# Comment: .
# Finished 283/15
# Grade: 5. Comment: .
# Finished 284/15
# Since there is no comment provided, I will assume that the criteria for "Stakeholders" in the "stakeholder" attribute does not contain an individual's name.
#
# Grade: 5
# Comment: .
# Finished 285/15
# Grade: 5
# Comment: .
# Finished 286/15
# Grade: 5
# Comment: .
# Finished 287/15
# Grade: 5. Comment: .
# Finished 288/15
# File name: input7.txt
# Since the comment mentions "project milestone", which implies that the project details (including the "Project Name:" attribute) are not specified, I will give this criteria a grade of 0.
#
# Here is the output:
#
# Grade: 0. Comment: the project milestone doesn't look right
# Finished 289/15
# Grade: 5
# Comment: None
# Finished 290/15
# Grade: 5. Comment: None
# Finished 291/15
# Grade: 5. Comment: None
# Finished 292/15
# Grade: 5
# Comment: . None
# Finished 293/15
# Here is the output:
#
# Grade: 5
# Comment: None
# Finished 294/15
# Grade: 5. Comment: None
# Finished 295/15
# Grade: 5. Comment: .
# Finished 296/15
# Since the comment is None, I will give this criteria a grade of 5.
#
# Grade: 5. Comment: None
# Finished 297/15
# Grade: 5. Comment: None
# Finished 298/15
# Grade: 5. Comment: None
# Finished 299/15
# Grade: 5. Comment: . None
# Finished 300/15
# Grade: 5. Comment: None
# Finished 301/15
# Grade: 5
# Comment: .
# Finished 302/15
# Grade: 5. Comment: .
# Finished 303/15
# Grade: 5. Comment: .
# Finished 304/15
# Grade: 5
# Comment: .
# Finished 305/15
# Grade: 5. Comment: .
# Finished 306/15
# Grade: 5. Comment: .
# Finished 307/15
# Grade: 5
# Comment: .
# Finished 308/15
# Grade: 5. Comment: .
# Finished 309/15
# Grade: 5. Comment: .
# Finished 310/15
# Grade: 5
# Comment: .
# Finished 311/15
# Grade: 5
# Comment: .
# Finished 312/15
# File name: input8.txt
# Grade: 0. Comment: the project milestone lack detail
# Finished 313/15
# Grade: 0. Comment: the project milestone lack detail
# Finished 314/15
# Grade: 0. Comment: the process attribute name not mentioned in the file.
# Finished 315/15
# Grade: 0. Comment: the process attribute name not mentioned in the file.
# Finished 316/15
# Grade: 5. Comment: the process attribute name not mentioned in the file.
# Finished 317/15
# Since the comment does not mention anything about the "Project Description / Purpose" attribute or section, I will give it a grade of 5.
#
# Output:
# Grade: 5
# Comment: the process attribute name not mentioned in the file.
# Finished 318/15
# Since the comment doesn't mention the "Project Description / Purpose" attribute, I'll assume it's irrelevant to this criteria. According to the instructions, if there's no mention of the section or criteria, the grade should be 5.
#
# Output:
# Grade: 5
# Comment: the process attribute name not mentioned in the file
# Finished 319/15
# Since the comment doesn't mention "Project Description / Purpose" or this specific criteria, I'll assume it's irrelevant to the grading. Therefore:
#
# Grade: 5. Comment: the process attribute name not mentioned in the file
# Finished 320/15
# Since the comment does not mention anything about the "Problem Summary:" attribute or this section, I will give it a grade of 5. Here is the output:
#
# Grade: 5. Comment: the process attribute name not mentioned in the file
# Finished 321/15
# Grade: 5. Comment: None.
# Finished 322/15
# Grade: 5. Comment: None.
# Finished 323/15
# Grade: 5. Comment: None.
# Finished 324/15
# Grade: 5. Comment: None.
# Finished 325/15
# Grade: 5
# Comment: .
# Finished 326/15
# Grade: 5. Comment: .
# Finished 327/15
# Grade: 5. Comment: .
# Finished 328/15
# Grade: 5. Comment: .
# Finished 329/15
# Since the comment is empty, I will assign a grade of 5.
#
# Grade: 5
# Comment: .
# Finished 330/15
# Grade: 5
# Comment:
# Finished 331/15
# Since the comment is empty (i.e., there is no text), I will assign a grade of 5.
#
# Grade: 5. Comment:
# Finished 332/15
# Grade: 5. Comment: None (since there's no comment provided).
# Finished 333/15
# Grade: 5
# Comment: None (since there's no comment provided).
# Finished 334/15
# Grade: 5. Comment: None (since there's no comment provided).
# Finished 335/15
# Grade: 5
# Comment: None (since there's no comment provided).
# Finished 336/15
# File name: input9.txt
# Based on the comment, I generate the grade for this criteria as follows:
#
# Grade: 0
# Comment: This comment does not mention the specific criteria ("Does the name of the 'Project Name:' attribute specified in the file?"), so it is given a grade of 0.
# Finished 337/15
# Grade: 5. Comment: None.
# Finished 338/15
# Grade: 5. Comment: None.
# Finished 339/15
# Grade: 5. Comment: None.
# Finished 340/15
# Grade: 5. Comment: None.
# Finished 341/15
# Grade: 5. Comment: None.
# Finished 342/15
# Here is the output:
#
# Grade: 5
# Comment: . Comment: None.
# Finished 343/15
# Grade: 5. Comment: None.
# Finished 344/15
# Grade: 5. Comment: None.
# Finished 345/15
# Grade: 5. Comment: None.
# Finished 346/15
# Grade: 5. Comment: None.
# Finished 347/15
# Grade: 5. Comment: None.
# Finished 348/15
# Grade: 5. Comment: None.
# Finished 349/15
# Grade: 5. Comment: None.
# Finished 350/15
# Grade: 5. Comment: None.
# Finished 351/15
# Grade: 5. Comment: .
# Finished 352/15
# Since the comment is empty (i.e., it's an empty string), I will assign a grade of 5.
#
# Grade: 5
# Comment: .
# Finished 353/15
# Grade: 5. Comment: .
# Finished 354/15
# Since there is no comment provided, I will assume that this criteria has not been evaluated and therefore deserves a perfect score.
#
# Grade: 5
# Comment: .
# Finished 355/15
# Grade: 5. Comment: .
# Finished 356/15
# Since the comment is empty (i.e., there is no comment), I will assign a grade of 5 to the "Stakeholders" attribute.
#
# Grade: 5. Comment: .
# Finished 357/15
# Grade: 5. Comment: .
# Finished 358/15
# Since the comment is empty (i.e., there is no comment), I will assign a grade of 5 to this criteria.
#
# Output:
# Grade: 5
# Comment:
# Finished 359/15
# Grade: 5. Comment: None.
# Finished 360/15
# Finished generating real grade.
#        filename      Section  \
# 0     input.txt  Description
# 1     input.txt  Description
# 2     input.txt  Description
# 3     input.txt  Description
# 4     input.txt  Description
# ..          ...          ...
# 355  input9.txt         Team
# 356  input9.txt         Team
# 357  input9.txt         Team
# 358  input9.txt         Team
# 359  input9.txt         Team
#
#                                               Criteria Real_Grade
# 0    1. Does the name of the "Project Name:" attrib...          5
# 1    2. Does the name of the "Clinic:" attribute sp...          5
# 2    3. Does the name of the "Process:" attribute s...          5
# 3    4. Does the name of the "TIP 2.0 Process Miles...          5
# 4    5. Does the name of the "TIP 2.0 Process Miles...          5
# ..                                                 ...        ...
# 355  4. Does the value of the "Process Manager:" at...          5
# 356  5. Does the value of the "Stakeholders" "stake...          5
# 357  6. Do the "Stakeholders" contain values for th...          5
# 358  7. Does the value of the "Project Team Members...          5
# 359  8. Do the "Project Team Members" contain role ...          5
#
# [360 rows x 4 columns]

# %%
real_grade_df.to_csv("real_result_on_14_submissions_v4.csv")

# %% [markdown]
# # Submission Class

# %%
from langchain import PromptTemplate
from langchain_core.prompts.few_shot import FewShotPromptTemplate

import pandas as pd
import numpy as np
import os
from beeprint import pp
import re
import requests
import sys

# Add the directory containing grading_prompts.py to the Python path
sys.path.append(os.path.abspath('rubric_files/'))
from grading_prompts import grading_prompts_v4, grading_prompts_v5, grading_prompts_v6, grading_prompts_v7, grading_prompts_v8
from criteria_dict import criteria_dict_v1, criteria_dict_v2, criteria_dict_v3
from AutomatePromptEngineer import SubmissionGrader, FolderProcessor

# %% [markdown]
# ## Generate Output DataFrame for All Files in Test Input Folder

# %%
# Example usage
folder_path = 'auto_grading_trainingset/input_files'
grading_prompts = grading_prompts_v8
grading_criterias = criteria_dict_v2
prompt_version = 8
criteria_version = 2

processor = FolderProcessor(folder_path, grading_prompts, grading_criterias, prompt_version, criteria_version)
processor.grade_files_in_folder()
# Out:
# Start grading for auto_grading_trainingset/input_files\input.txt...
# Grade: 5. Comment: The submission provides a clear and detailed description of the project, including its name, clinic, process, and purpose. It also meets the criteria for providing multi-sentence responses that explain the context and goals of the project. The language used is concise and effective in conveying the importance of addressing barriers to healthcare access and promoting health equity. Overall, this submission excels in meeting the requirements for a high-quality description section.
# Grade: 5
# Comment: This submission meets the criteria perfectly, providing a detailed and multi-sentence response in the Description section. The description clearly states the purpose of the project, which is to identify and address barriers that lead to higher rates of missed appointments among publicly insured patients, with the goal of promoting health equity within the patient population.
# Grade: 5. Comment: This submission meets the requirements perfectly! It includes a clear and concise description of the project's purpose, which aligns with the attribute "Process:". The language is also very detailed, providing a good understanding of what the project aims to achieve. Overall, this submission exceeds expectations.
# Grade: 5
# Comment: The submission provides a detailed, multi-sentence response that properly lists the "TIP 2.0 Process Milestone" attribute. The description clearly states the purpose of the project, which is to identify and address barriers to accessing healthcare services for patients with public insurance, ultimately promoting health equity within the patient population.
# Grade: 5. Comment: The submission meets all the requirements, providing specific milestone information for the "TIP 2.0 Process Milestone" attribute, which is "Health Equity". This demonstrates a clear understanding of the project's purpose and goals, including addressing barriers to healthcare access and promoting health equity among publicly insured patients.
# Grade: 5. Comment: This submission provides a detailed, multi-sentence response that effectively summarizes the project's purpose and goals. It clearly states the problem being addressed (barriers to accessing healthcare services for patients with public insurance), the aim of the project (to identify and address these barriers), and the desired outcome (increasing appointment completion rates). The language is concise yet informative, making it easy to understand the project's objectives.
# Grade: 5. Comment: This submission clearly states the goal or purpose of the project, providing a detailed and multi-sentence response that outlines the problem being addressed (barriers to accessing healthcare services for patients with public insurance) and the desired outcome (increasing completed primary care appointments among this patient population).
# Grade: 5. Comment: This submission meets all criteria for a detailed description of the project's purpose and expected results. The text provides a clear explanation of the problem being addressed (barriers to accessing healthcare services for publicly insured patients), the goal of the project (increasing appointment completion rates among this population), and the desired outcome (improving access to healthcare and promoting health equity).
# Grade: 5. Comment: The "Problem Summary" provides a detailed and logical description of the problem related to the project. It clearly identifies the performance gap in completing primary care appointments among patients with public insurance, its impact on patients and healthcare providers, and the benefits of addressing this issue. The summary also sets the stage for the rest of the project by highlighting the importance of health equity and the need for targeted interventions to improve appointment adherence.
# Grade: 5
#
# Comment: The "Desired Outcome(s)" attribute provides a detailed and multi-sentence response describing the expected outcomes of the project. Specifically, the submission mentions increasing the percentage of completed primary care appointments among individuals with public insurance by 20% within three months, which aligns with the project goal. Additionally, the submission highlights the benefits of achieving this outcome, including improved health outcomes, reduced healthcare costs, and promoted health equity. The response is thorough and provides a clear understanding of what the project aims to achieve.
# Grade: 5
#
# Comment: The "Benefits:" attribute provides a detailed, multi-sentence response that clearly describes the benefits of the project. It outlines how improving completed primary care appointments among patients with public insurance will enhance health outcomes, reduce healthcare costs, improve patient engagement and satisfaction, promote health equity, empower vulnerable populations, optimize resource utilization, strengthen community health, and create a more efficient and equitable healthcare system. The response is comprehensive and effectively communicates the value of the project.
# Grade: 4. Comment: The timeline section provides a clear and concise list of tasks with corresponding month numbers, indicating that the project will span at least three months. The task list covers several essential steps in the process, including planning, intervention development, implementation, and monitoring and evaluation. However, some tasks could be further elaborated upon, such as what specific data was collected during the analysis phase or what adjustments were made to strategies based on feedback. Nevertheless, this submission meets most of the requirements and provides a solid foundation for understanding the project's timeline.
# Grade: 5. Comment: The submission provides a clear and detailed timeline for each task, including specific due dates for some tasks. For example, Task 1 spans one month, while Task 3 is implemented over two months (Months 2 and 3). Additionally, the submission notes that data collection will occur during Month 1 and adjustment strategies based on data and feedback will take place in Month 3.
# Grade: 4. Comment: The "In Scope Project Objectives" clearly define the core purpose of the project as managing primary care appointments for patients with public insurance (Medicaid and Medicare). The scope is well-defined and concise, making it easy to understand what is included within the project's boundaries. However, the comment could be expanded to provide more context or clarification on why these objectives are important or how they will be achieved.
# Grade: 5. Comment: The submission provides a clear "In Scope" section listing the primary care appointments that fall within the project's objectives, as well as an "Out of Scope" section that explicitly defines what is not included in the project. This level of detail and clarity is exemplary, earning a score of 5.
# Grade: 3
#
# Comment: The scope section provides a clear distinction between what is in-scope and out-of-scope for the project. The in-scope objectives are specific (primary care appointments for patients with public insurance) and easy to understand. However, the responses could be more detailed by explaining why these objectives align with key project milestones.
# Grade: 4. Comment: The "Team Lead:" attribute is filled with the team lead's name, Jim Mergy, which meets the requirements. However, a more detailed description of the team lead's role and responsibilities would have earned a perfect score of 5. Overall, this submission provides the necessary information about the team members and their roles, but could be improved by providing more context about the team lead's involvement in the project.
# Grade: 5. Comment: The "Project Champion:" attribute is correctly filled with a person's name, Anthony Amezquita. The submission provides all the necessary team-related information, including the Project Champion, Process Owner, and Process Manager. Additionally, it lists specific stakeholders and team members with their respective roles. Overall, this submission meets the requirements thoroughly and provides detailed information, hence deserving a grade of 5.
# Grade: 5. Comment: The submission provides the necessary information for the "Process Owner:" attribute by specifying Lisa Kilburn as the owner, making it a detailed and multi-sentence response.
# Grade: 5. Comment: The "Process Manager:" attribute is properly populated with Nicole Valenzuela, meeting the requirements and providing detailed information.
# Grade: 5. Comment: The submission provides detailed and multi-sentence responses, including the names of team members in the "stakeholder" attribute for the stakeholders section. It also includes a clear list of project team members with their roles, making it easy to identify who is responsible for specific tasks within the project.
# Grade: 4. Comment: The submission provides the necessary information for the "Stakeholders" section, including title, department, and organization. However, it would be even more effective if a brief description or role was included for each stakeholder to provide further context about their involvement in the project.
# Grade: 5. Comment: The "Project Team Members" section meets the requirements by including individual names in the "Name" attribute, with each team member listed along with their corresponding team role. The submission is clear and easy to understand, making it a strong candidate for a high grade.
# 2024-10-23 13:24:22,065 - INFO - Finished 1 / 15
# Grade: 5. Comment: The "Project Team Members" section provides the team roles in the "Team role" attribute, and the responses are detailed enough to indicate the specific responsibilities of each team member.
# Finished grading auto_grading_trainingset/input_files\input.txt.
#
# Start grading for auto_grading_trainingset/input_files\input10.txt...
# Grade: 5. Comment: The submission provides detailed and multi-sentence responses that effectively describe the project's purpose, including its significance and benefits.
# Grade: 5
# Comment: The submission meets all the requirements, providing a detailed description of the project, including the attribute "Clinic:". The language is clear and concise, effectively conveying the purpose and importance of screening for social determinants of health. The inclusion of specific benefits, such as improved health outcomes and decreased emergency room visits, adds depth to the description. Overall, this submission receives a grade of 5 for its thorough and well-written description.
# Grade: 5. Comment: The submission provides a clear and detailed description of the process, including specific steps such as "Distribution of screening tool", "documentation of results", and "closed loop referral process for needed concerns". The language is concise and easy to understand, making it a strong example of meeting the criteria for this attribute.
# Grade: 5
# Comment: The submission meets all criteria, including providing the necessary information about the project description and purpose. Additionally, it provides detailed and multi-sentence responses that demonstrate a clear understanding of the topic.
# Grade: 5. Comment: The submission meets all criteria for providing specific milestone information. The "TIP 2.0 Process Milestone" attribute is clearly labeled as "Milestone 3", indicating that this description corresponds to a specific point in the process. Additionally, the provided information about the screening tool, documentation of results, and closed-loop referral process provides detailed context for what occurs at this milestone.
# Grade: 4. Comment: The project description provides a clear summary of the project's purpose, which is to screen for social determinants of health (SDOH) to identify barriers to seeking healthcare, lifestyle choices, and safety concerns that impact patients' health outcomes. The description also highlights the benefits of SDOH screening, including improved health outcomes, reduced emergency room visits, and increased establishment of healthy habits. While the description could be expanded to include more details on the specific process or expected outcomes, it provides a solid foundation for understanding the project's purpose and goals.
# Grade: 4
#
# Comment: The project description clearly states the goal or purpose of the project, which is to screen for health-related social needs (social determinants of health) to assess lifestyle and social factors that impact health. The description also highlights the benefits of screening, including improved health outcomes, reduced emergency room visits, and establishment of healthy habits. Additionally, it mentions the importance of screening in a pediatric primary care practice, emphasizing its impact on both the patient and their family. The only area for improvement is that the description could be more detailed and provide specific examples or goals for the project. Overall, it provides a clear purpose and direction for the project.
# Grade: 4
#
# Comment: The project description provides a good overview of the purpose and expected results of the Social Determinants of Health Screening project. It clearly explains how screening for health-related social needs can positively impact health outcomes, reduce emergency room visits, and improve healthy habits. Additionally, it highlights the benefits of screening in a pediatric primary care practice, including its impact on both the child and the family's overall health. While the description could be slightly more detailed, it provides sufficient information to understand the project's purpose and expected results.
# Grade: 4. Comment: The "Problem Summary:" section provides a logical description of the problem related to the project, including an overview of the benefits of universal screening for health-related social needs (HRSN) in the pediatric population. The section highlights the importance of addressing these needs to improve health outcomes and reduce healthcare costs, as well as decrease health disparities. It also mentions specific barriers to receiving care, such as time limits and clinicians' feelings of inadequacy. The section could be improved by providing more detail on the current state of HRSN screening in pediatric settings and how this project addresses these gaps. Overall, the problem summary is clear and concise, providing a solid foundation for the project's goals and objectives.
# Grade: 4. Comment: The "Desired Outcome(s)" section is well-filled, providing five clear and specific goals for the program. Each outcome is concise and focused on a particular aspect of the program's objectives, such as increasing routine screening, connecting families with resources, and decreasing barriers to healthcare. The only reason it doesn't receive a 5 is that each outcome is quite brief and lacks additional details or context.
# Grade: 4. Comment: The "Benefits:" attribute provides a good description of the benefits of the project, stating that effective screening will lead to a decrease in social needs that negatively impact health and improved health outcomes for children, families, and later adults. The response is not overly detailed or multi-sentence, but it does provide a clear and concise summary of the expected benefits.
# Grade: 4. Comment: The task list provides a clear outline of the essential tasks in the project, including researching and choosing an evidence-based HRSN screening tool, developing relationships with community-based referral organizations, and piloting and implementing the screening workflow. However, the submission could be improved by providing more detail on what each task entails, such as specific deliverables or milestones. Additionally, it would be helpful to have a clear indication of who is responsible for completing each task, although this information is not provided in the current submission. Overall, the submission meets most of the requirements, but lacks some level of detail and specificity.
# Grade: 5. Comment: The submission provides detailed information on each task, including specific due dates, making it easy to track progress and plan accordingly. Each task has a clear deadline, allowing for effective planning and management of the project timeline.
# Grade: 5. Comment: The "In Scope Project Objectives" clearly reflect the project's core purpose of establishing an effective and efficient HRSN (SDOH) screening workflow for pediatric primary care practices of Arbor Medical Partner, including a closed loop referral process that connects families with needs with a community-based referral resource. The objective is well-defined, specific, and measurable, indicating a clear understanding of what the project aims to achieve.
# Grade: 5. Comment: The submission meets the requirements by providing a clear "In Scope" section stating the project objective, and an "Out of Scope" section explicitly listing non-aligned objectives or activities. The "Out of Scope" section is detailed and multi-sentence, providing specific examples of what is not included in this project.
# Grade: 4
#
# Comment: The submission provides clear and concise in-scope project objectives that are aligned with key milestones. The objective is well-defined, stating the goal of establishing an effective and efficient HRSN (SDOH) screening workflow for pediatric primary care practices. Additionally, the out-of-scope activities or objectives are clearly stated, providing a clear understanding of what is not included in this project. However, it would be even stronger if the submission provided more details on how these objectives align with specific key project milestones.
# Grade: 4. Comment: The "Team Lead:" attribute is filled with the team lead's name, which is Karen Eynon. Additionally, the submission provides detailed information about other team members, including their roles and titles. However, it would be even stronger if a brief description or explanation of the team lead's role were provided to give context and clarify their responsibilities within the project.
# Grade: 5. Comment: The "Project Champion:" attribute is correctly filled with a person's name, Karen Eynon, and it is accompanied by a brief description of their role. This submission provides detailed information about the project team members' roles and stakeholders, which meets the requirements.
# Grade: 4. Comment: The submission meets the requirements by specifying the owner's name, "Raegan Post", as the Process Owner. However, it would be even more detailed to provide a brief description of Raegan's role or responsibilities in regards to the process ownership.
# Grade: 5. Comment: The submission provides detailed and comprehensive information about the team members, roles, and stakeholders involved in the project. The "Process Manager:" attribute is properly populated with Karen Eynon's name, indicating her responsibility for managing the process. Additionally, the submission includes a clear list of stakeholders, their titles, departments, and organizations, as well as a separate section for project team members with their names and roles.
# Grade: 5. Comment: The submission provides a comprehensive list of stakeholders, including their titles, departments, and organizations. Additionally, the team members are listed with their names and roles, providing clear information about who is involved in the project. The level of detail is excellent, making it easy to identify key individuals and understand their responsibilities.
# Grade: 5
#
# Comment: The submission provides detailed information about the stakeholders, including their title, department, and organization. Each stakeholder is labeled correctly with their role in the project. The format is clear and easy to read, making it simple to identify the different stakeholders and their roles. The submission meets all of the necessary criteria, providing a comprehensive overview of the team involved in this project.
# Grade: 5. Comment: This submission meets the requirements by providing individual names in the "Name" attribute for all team members, including the Team Lead, Project Champion, Process Owner, and Process Manager. The Stakeholders section also provides individual names for the stakeholders involved. The Project Team Members section lists each team member's name and role, making it easy to identify who is responsible for what tasks within the project.
# 2024-10-23 13:26:08,687 - INFO - Finished 2 / 15
# Grade: 5. Comment: The "Project Team Members" section clearly provides the team roles for each member, including the names and brief descriptions of their responsibilities. This submission meets the requirements with detailed, multi-sentence responses.
# Finished grading auto_grading_trainingset/input_files\input10.txt.
#
# Start grading for auto_grading_trainingset/input_files\input11.txt...
# Grade: 4
#
# Comment: The project name is indeed mentioned in the file, which meets the requirement. The description provides a brief purpose statement, but it would benefit from more detail and context about what the HRSN screening process entails. A higher grade could be achieved if the description included more specific information about the goals of the process, the steps involved, or the expected outcomes.
# Grade: 4. Comment: The submission provides the necessary information by including the attribute "Clinic:" with a value of "HRT", which meets the criteria. However, the response could be more detailed and provide additional context about the project's purpose and scope. Overall, the submission provides some relevant information but lacks depth in its description.
# Grade: 4. Comment: The submission meets the requirements by including the "Process:" attribute, providing a brief description of the process, and mentioning specific components such as screening, documentation, diagnosis, and referrals. However, it would benefit from more detail and elaboration on each component to fully meet the criteria for a grade of 5.
# Grade: 3
# Comment: The submission meets the requirements by listing the "TIP 2.0 Process Milestone:" attribute, specifically mentioning the "Core Component 3 Process for Screening for HRSN". However, it would be even stronger if the description provided more detail about the process and its purpose, rather than just stating that the screening process needs to be implemented.
# Grade: 1
# Comment: The submission does not provide specific milestone information, only mentioning a "Core Component 3" without providing details about the milestone. A higher grade would require more specific and descriptive information about the milestone, such as dates, tasks, or deliverables.
# Grade: 1
# Comment: The submission does not provide a brief summary of the project, nor does it provide any detailed information. It only states that the "HRSN screening process needs to be implemented", which is too vague and does not meet the criteria for a clear project description. A more detailed description of the purpose and scope of the project would be expected in this section.
# Grade: 1
# Comment: The project description does not clearly state the goal or purpose of the project, only stating that the HRSN screening process "needs to be implemented". A clearer and more detailed statement of the project's purpose is necessary.
# Grade: 1
# Comment: The submission does not provide a detailed description of the project's purpose or expected results, only stating that the HRSN screening process "needs to be implemented". This falls short of meeting the requirements for a clear and concise project description.
# Grade: 4. Comment: The submission provides a logical problem description related to the project, identifying specific barriers that need to be addressed in order to report data on the process. However, it could be more detailed by providing a clear statement of the problem and its significance, which is not entirely evident from the current summary.
# Grade: 3. Comment: The submission does provide a brief mention of the desired outcome ("We are currently not able to report data on this process."), but it is not a detailed, multi-sentence response. It meets the minimum requirement, but lacks depth and clarity in describing the expected outcomes.
# Grade: 0. Comment: The submission does not provide any information about the benefits of the project. It only provides a problem summary and identified barriers, but does not describe the benefits that the project will bring.
# Grade: 3. Comment: The task list covers some essential tasks in the project, but it could be more detailed and comprehensive. Tasks 1-4 seem to cover the main activities related to implementing PCAM (Patient-Centered Assessment Measure) and HRSN (Hospice Rating System of Nursing), including training staff, streamlining EHR processes, tracking completion rates, and conducting root cause analyses as needed. However, Task 5 seems more like a reporting requirement rather than a specific activity. A more detailed task list that breaks down these activities into smaller, manageable tasks would be beneficial for this project.
# Grade: 4. Comment: The submission provides a clear list of tasks with specific descriptions, which meets the requirement for including task details. While it doesn't explicitly state due dates for each task, it does provide completion frequencies (e.g., "at minimum monthly" for Task 4). A more detailed or explicit indication of due dates would elevate this to a perfect score of 5. Overall, a good effort!
# Grade: 3. Comment: The "In Scope Project Objectives" provide a brief summary of the project's purpose, which is to improve the use of PCAM in intake and annual assessments using an improvement plan. However, the responses are quite short and do not fully reflect the project's core purpose or specific goals. A more detailed description of the objectives would be beneficial for a higher grade.
# Grade: 5. Comment: The submission provides a clear "In Scope" section stating the project objective to improve the use of PCAM in intake and annual assessment, which meets the requirement. Additionally, it includes a well-structured "Out of Scope" section that explicitly states there are no identified objectives outside the scope at this time, with a provision for future adjustments if needed. The submission provides detailed information, making it clear what is included and what is not, thus earning a high grade.
# Grade: 3. Comment: The submission provides a clear distinction between in-scope and out-of-scope project objectives, which meets the requirement. However, the responses could be more detailed, specifically in the "In Scope" section where only one objective is mentioned without much elaboration on its alignment with key project milestones.
# Grade: 0
# Comment: The "Team Lead:" attribute is not filled with the team lead's name. To meet the criteria, please provide the name of the team lead.
# Grade: 0
# Comment: This submission does not provide any information about the "Project Champion:" attribute or the person's name.
# Grade: 0. Comment: The submission does not provide the necessary information to meet the criteria, as it only includes a single attribute "Team Lead:" without specifying the owner by name.
# Grade: 0
# Comment: The submission does not provide any information about the "Process Manager:", which is a required attribute according to the criteria.
# Grade: 0. Comment: The submission does not provide any information about stakeholders with names in the "stakeholder" attribute, which is a crucial piece of information for assessing stakeholder engagement and involvement in the project. To meet the criteria, the team section should include a list of stakeholders with their names and roles, indicating who they are and what they bring to the project.
# Grade: 2. Comment: The "Stakeholders" section only includes one person, the "Team Lead", without providing their title, department, or organization. While some information is provided, it does not meet the full criteria of including title, department, and organization for each stakeholder.
# Grade: 1. Comment: The "Project Team Members" section only includes one team member's name, which is the Team Lead, but does not provide any additional information such as individual names in the "Name" attribute. A more detailed and comprehensive list of team members is necessary to meet this requirement.
# 2024-10-23 13:27:42,207 - INFO - Finished 3 / 15
# Grade: 1. Comment: The "Team" section only lists one team member with no indication of their role on the project. To meet the requirements, the section should include a description of each team member's role, such as "Project Manager", "Designer", or "Researcher".
# Finished grading auto_grading_trainingset/input_files\input11.txt.
#
# Start grading for auto_grading_trainingset/input_files\input12.txt...
# Grade: 3. Comment: The submission mentions the purpose of the project, but it does not provide a clear "Project Name:". While it provides some context about the project's goals and objectives, it lacks a concise and descriptive title for the project.
# Grade: 3. Comment: The submission does mention "Clinic:" in its description, but only as part of the organization name ("EMPACT-SPC"). It would be more helpful to include a specific attribute or header labeled "Clinic:" that explicitly indicates this project is related to a clinic or healthcare setting.
# Grade: 3. Comment: The submission meets the requirements for including the "Process:" attribute, but does not provide a detailed description of the process. It only mentions that screening clients is needed to better understand and act on SDOH, and states the purpose of the project in increasing the percentage of completed PRAPARE screenings.
# Grade: 3. Comment: The submission provides a general overview of the project's purpose, but does not specifically mention the "TIP 2.0 Process Milestone:" attribute. While it mentions the percentage increase goal for PRAPARE screenings, it does not explicitly state that this milestone is part of the TIP 2.0 process.
# Grade: 3. Comment: The submission provides some specific information about the milestone, including the goal percentage of completed PRAPARE screenings (at least 85%) and the timeframe for achieving this goal (October 1, 2024 to March 31, 2025). However, it could be more detailed by providing additional information about what constitutes a "completed screening" or specific steps that will be taken to increase the percentage of completed screenings.
# Grade: 3. Comment: The submission provides a brief summary of the project, stating the purpose and goal of increasing the percentage of completed PRAPARE screenings. However, it could be more detailed by providing an overview of what the screening tool is and how it will help better understand and act on clients' Social Determinants of Health.
# Grade: 5
#
# Comment: This submission clearly states the goal or purpose of the project in a detailed and multi-sentence response. The language is concise and effectively communicates the objective of increasing the percentage of completed PRAPARE screenings to at least 85% of clients seen by EMPACT-SPC within a specific timeframe.
# Grade: 4. Comment: The submission provides a clear purpose for the project, which is to increase the percentage of completed PRAPARE screenings among EMPACT-SPC clients. It also mentions expected results, specifically increasing the completion rate to at least 85%. However, it would be even stronger if it provided more detail on what this increase in screening completions will achieve or how it will impact SDOH for EMPACT-SPC's clients.
# Grade: 3. Comment: The "Problem Summary" provides some information about the issue being addressed, but it is quite brief and does not fully describe the problem. It mainly focuses on the benefits of using the PRAPARE Tool rather than clearly defining the problem itself. A more detailed description of the problem would be helpful to better understand its significance and the need for a solution like this project.
# Grade: 4. Comment: The submission provides a decent description of the expected outcomes, but it could be more detailed and explicit. For example, it would be helpful to know what specific improvements are expected in the health and well-being of EMPACT-SPC clients or how the connection to community resources will specifically benefit them. Overall, the submission meets the requirements, but could provide more depth and clarity in its response.
# Grade: 4. Comment: The submission meets the requirements, providing a clear description of the benefits of the project in two sentences. It highlights the potential outcome of the 85% screening rate, which is to identify risk factors that can be addressed internally or by connecting clients to external resources. Additionally, it mentions how addressing these risk factors will improve the health and well-being of EMPACT-SPC clients and connect them to necessary community resources.
# Grade: 3. Comment: The timeline section provides a list of tasks with their corresponding completion dates. While it meets the basic requirement of providing essential information, the descriptions are quite brief and do not provide much detail about each task. To achieve a higher grade, more detailed explanations about what each task entails and specific milestones would be helpful.
# Grade: 5.
# Comment: The submission provides specific due dates for each task, which meets the criteria perfectly. The format is clear and easy to understand, and it's great that Task 3 has a recurring due date starting from November 1, 2024. Overall, this submission effectively demonstrates how each task has a specific due date, which warrants a grade of 5.
# Grade: 4. Comment: The "In Scope Project Objectives" clearly state the main objective of the PRAPARE Implementation project, which is to increase the usage of the HRSN Screening Tool and achieve a minimum utilization rate for EMPACT-SPC clients. The response is concise and specific, providing clear direction on what the project aims to accomplish. However, it would be even stronger if it provided more detail on why this objective is important or what specific strategies will be used to achieve it.
# Grade: 5. Comment: This submission meets the requirements by clearly stating the main objective and including an "Out of Scope" section that explicitly outlines what is not included in the project. The language used in both sections is concise yet clear, providing a comprehensive understanding of the scope of the project.
# Grade: 3. Comment: The submission provides a clear in-scope objective and a brief statement about what is out of scope, but it could be improved by providing more detail on how these objectives align with key project milestones.
# Grade: 5. Comment: The submission meets the requirements with a detailed and multi-sentence response, providing the name of the team lead ("Sarah Nadler-Population") along with a list of team members and their roles, making it easy to identify the team structure.
# Grade: 5. Comment: The "Project Champion:" attribute is not explicitly mentioned in this submission, but it seems that the Team Lead, Sarah Nadler-Population, may be acting as a champion for the project. The team section provides clear information about each team member's role and department, which meets the requirements. A 5-grade is given because the response includes detailed, multi-sentence responses about each team member's role.
# Grade: 3. Comment: The submission provides the necessary information, specifying the owner by name ("Team Lead: Sarah Nadler-Population"). However, it could be improved with more detail about what it means to be the process owner or a brief description of their role in overseeing this project.
# Grade: 5
# Comment: The submission provides a comprehensive list of team members, including the "Team Lead" and various roles such as Program Manager, Associate Director, and SQL Database Administrator. The information is well-organized and easy to read, with each team member's name and role clearly listed.
# Grade: 5. Comment: The submission provides a clear list of stakeholders with names in the "stakeholder" attribute, along with their titles, departments, and organizations. Additionally, it includes a separate section for project team members, specifying each member's role. The level of detail provided meets the requirements, earning a score of 5.
# Grade: 5. Comment: The submission meets the requirements by providing clear labels for the "Stakeholders" section, including title, department, and organization for each individual. Additionally, the "Project Team Members" section provides necessary information about team members' roles. Overall, this submission is well-organized and easy to follow.
# Grade: 5. Comment: This submission meets the requirements with flying colors! The "Project Team Members" section not only contains individual names in the "Name" attribute but also provides detailed information about each team member's role, including their title and department. The inclusion of organization and stakeholder titles adds an extra layer of transparency and clarity. Overall, this submission is well-organized and provides all the necessary information.
# 2024-10-23 13:29:21,911 - INFO - Finished 4 / 15
# Grade: 5. Comment: The submission meets the requirements by providing the necessary information about team roles in the "Team role" attribute. The "Project Team Members" section clearly lists each team member's name and their corresponding team role, which is a detailed and specific response to this criterion.
# Finished grading auto_grading_trainingset/input_files\input12.txt.
#
# Start grading for auto_grading_trainingset/input_files\input14.txt...
# Grade: 5. Comment: The submission meets all requirements, providing the necessary information in a concise manner.
# Grade: 4. Comment: The submission meets the requirements by including the attribute "Clinic:" with a specific value ("All Denova Clinics"). Additionally, it provides a brief description of the project's purpose, which is to utilize SDOH data to identify inequities. However, the response could be more detailed and multi-sentenced to receive a perfect score.
# Grade: 4. Comment: The submission meets the requirements by including the "Process:" attribute, which specifies how the equity in health project will utilize SDOH data to identify inequities. However, the response could be more detailed and provide a clearer explanation of the process, which would warrant a higher grade.
# Grade: 3
#
# Comment: The submission meets the requirements by listing the "TIP 2.0 Process Milestone:" attribute, specifically stating that it is "Milestone 3". However, it would be more comprehensive to provide a brief explanation or context about what this milestone entails or how it relates to the overall project purpose.
# Grade: 1
# Comment: The submission does not provide specific milestone information for the "TIP 2.0 Process Milestone:". It only mentions the process and the milestone number, but does not provide any details about what the milestone entails or what tasks are involved.
# Grade: 2. Comment: The submission provides some basic information about the project, but it does not provide a detailed summary. It only mentions that the project involves using SDOH data, which is not enough to give a clear understanding of the project's purpose and scope. A more detailed description would be helpful in providing context and clarity on what the project aims to achieve.
# Grade: 3
# Comment: The submission provides a brief mention of the purpose of the project, stating that it involves using SDOH data. However, it does not provide a clear and detailed description of the goal or purpose of the project. To meet the criteria for a grade of 5, the submission would need to include more specific information about what the project aims to achieve and why it is important.
# Grade: 1
# Comment: The submission does not provide a detailed description of the expected project results, only stating the purpose of the project which is to utilize SDOH data. It does not mention what specific outcomes or achievements are expected from the project. A more detailed response is needed to meet this criterion.
# Grade: 5
#
# Comment: The "Problem Summary" section provides a detailed and logical description of the problem related to the project. It clearly explains that the current SDOH data collection is limited in analyzing health inequities and social needs, and that there is a need for a seamless reporting system to facilitate data analysis and guide interventions. The issue is framed as a challenge that hinders the practice's ability to provide comprehensive patient care and address health disparities, making it a compelling problem to solve.
# Grade: 5
# Comment: The submission provides a detailed and multi-sentence response for the "Desired Outcome(s)" attribute, meeting all criteria for this section. The desired outcomes are clearly outlined, including specific goals such as utilizing an existing ODBC connection to build Tableau reports, designing a seamless reporting system, and using data analysis to guide needed interventions.
# Grade: 5
#
# Comment: The "Benefits:" attribute provides a detailed and multi-sentence response that describes the benefits of the project in several areas, including enhanced patient care and outcomes, stronger patient-provider relationships, reduced complications and hospital readmissions, and improved health equity. The description also highlights the importance of addressing social determinants of health to promote holistic healthcare and mitigate health disparities.
# Grade: 4. Comment: The submission provides a clear list of tasks with corresponding completion dates, which meets the requirements for the Timeline section. However, it lacks detailed descriptions of each task, which would make the timeline more comprehensive and easier to understand. Additionally, there is no indication of critical milestones or key deliverables within each task, which could be important considerations in project planning. Overall, while the submission provides a good foundation, it falls short of providing a highly detailed and comprehensive timeline.
# Grade: 4. Comment: The submission provides a clear timeline with specific task names, descriptions, and due dates for each task. Each task has a unique due date, which meets the criteria. However, it would be more effective to have a brief description of what is expected to be completed by each due date, rather than just listing the tasks.
# Grade: 1
# Comment: The "In Scope Project Objectives" section is very brief and does not provide enough information to understand the project's core purpose. A more detailed description of what the project aims to achieve would be helpful in understanding its scope.
# Grade: 5
# Comment: The submission provides a clear "In Scope" section listing one objective ("Assessment and Planning") and an "Out of Scope" section with a single activity that is not aligned with the project objectives, specifically "Hiring additional staff". This submission meets the requirements thoroughly, making it deserving of a high grade.
# Grade: 3
#
# Comment: The submission provides a clear distinction between in-scope and out-of-scope project objectives. However, it would be beneficial to see more detail on the specific assessment and planning process used to determine what is in scope. Additionally, providing examples or rationales for why certain objectives are in or out of scope could strengthen this section.
# Grade: 4. Comment: The "Team Lead:" attribute is not explicitly filled with the team lead's name, but it does provide a list of project team members and their roles, which meets the requirement. However, a more detailed response would have included the team lead's name. Overall, this submission provides sufficient information to meet the requirements, but could be improved by including the team lead's name.
# Grade: 5. Comment: The submission provides a clear and detailed list of team members, including their names and roles. It also includes the "Project Champion:" attribute filled with a person's name, Henry Haun, who is the Director of Patient Experience Engagement Center.
# Grade: 3. Comment: The submission meets the requirements by providing the names of team members and their roles, but it does not specify the "Process Owner:" attribute by name.
# Grade: 3
#
# Comment: The "Process Manager:" attribute is not properly populated, as it does not appear in the provided Team section. However, the submission does provide a list of team members with their roles, which meets some parts of the requirement. To achieve a higher grade, the Process Manager's information should be included and detailed, multi-sentence responses are not necessary for this specific attribute.
# Grade: 5. Comment: The submission provides a comprehensive list of stakeholders with names in the "stakeholder" attribute, including the project team members and their roles. The inclusion of specific details about each team member's responsibilities adds depth to the listing, making it easy to understand who is involved in the project.
# Grade: 4. Comment: The "Stakeholders" section is mostly complete, as it includes the necessary information about title, department, and organization for each individual listed. However, to achieve a grade of 5, more detailed descriptions or roles would be required for the stakeholders. As it stands, the submission meets the requirements but lacks additional context that would enhance understanding of their involvement in the project.
# Grade: 5. Comment: The "Project Team Members" section clearly provides individual names in the "Name" attribute, which meets the requirements of this criterion. Each team member is listed with their name and role, making it easy to identify who is responsible for what tasks. The format is clear and concise, allowing readers to quickly understand the composition of the project team.
# 2024-10-23 13:30:59,796 - INFO - Finished 5 / 15
# Grade: 5. Comment: The "Project Team Members" section provides clear information on each team member's role, including a brief description of their responsibilities, which exceeds the minimum requirements.
# Finished grading auto_grading_trainingset/input_files\input14.txt.
#
# Start grading for auto_grading_trainingset/input_files\input15.txt...
# Grade: 4. Comment: The submission meets the requirements by including the "Project Name" attribute, providing a clear and concise description of the project's purpose and goals. However, it could be considered a 5 if the response was more detailed, perhaps elaborating on how the screening process will be implemented or what specific benefits are expected from increasing the percentage of patients completing the HRSN screening.
# Grade: 5. Comment: The submission provides a detailed and multi-sentence response that meets the criteria, including the attribute "Clinic:" which is required. The description also provides a clear purpose for the project, explaining why screening for health-related social needs is important and how it will be achieved through this project.
# Grade: 5. Comment: The submission provides a detailed description of the process involved in introducing HRSN screening at wellness visits, meeting the requirement for a multi-sentence response.
# Grade: 4
#
# Comment: The "TIP 2.0 Process Milestone:" attribute is listed correctly as "Milestone 2", indicating that the submission meets the requirement. The description also provides a brief overview of the project's purpose and importance, which suggests a good understanding of the topic. However, the response could be more detailed to receive a perfect score.
# ...
# Grade: 5. Comment: The submission provides a clear "In Scope" statement outlining the primary objective of the project, and also includes an "Out of Scope" section that explicitly lists non-aligned objectives or activities. The language is concise and easy to understand, providing a good example of how to effectively define scope for a project.
# Grade: 3. Comment: The submission provides the necessary information on in-scope and out-of-scope project objectives. However, it could be improved by providing more detail on how these objectives align with key project milestones. A simple list of objectives without explanation does not fully demonstrate alignment. Nevertheless, meeting the minimum requirements earns a score of 3.
# Grade: 4. Comment: The "Team Lead:" attribute is filled with the team lead's name, Emily Bofetta. Additionally, the submission provides information on the Project Champion, Process Owner, and Process Manager. However, it would be even more comprehensive to include a brief description of each person's role and responsibilities or how they contribute to the project.
# Grade: 5. Comment: The submission provides detailed information about the team members and roles. The "Project Champion:" attribute is correctly filled with a person's name, Shane Speirs, MD, which meets the requirements.
# Grade: 3. Comment: The submission provides the necessary information for the "Process Owner" attribute by specifying Sarah Davis as the owner. However, it does not provide a detailed description of the process owner's role or responsibilities.
# Grade: 5. Comment: The "Process Manager:" attribute is properly populated with Cassandra Anderson's name, providing the necessary information. The submission also includes a clear list of stakeholders and project team members, making it comprehensive and easy to understand. Overall, this submission meets all requirements and exceeds expectations.
# Grade: 5
#
# Comment: The submission provides detailed and multi-sentence responses for the "Team" section, including names with titles in the "stakeholder" attribute. The team members are listed with their roles, making it clear who is responsible for leading and contributing to the project. Overall, this submission meets the requirements thoroughly and accurately.
# Grade: 4. Comment: The submission meets the requirements for labeling stakeholders with their title, department, and organization, but falls short of providing detailed information. The "Stakeholders" section is well-organized, and the titles, departments, and organizations are clearly listed for each stakeholder. Additionally, the process owner, project manager, and team members are also identified. However, the responses could be more detailed by including a brief description of each stakeholder's role or their level of involvement in the project. Overall, the submission meets most of the requirements but lacks depth in its descriptions.
# Grade: 4. Comment: The submission meets the requirements by providing individual names in the "Name" attribute for most of the team members. However, it would be even more comprehensive if the project provided detailed descriptions or roles for each team member beyond just their title.
# 2024-10-23 13:45:42,487 - INFO - Finished 13 / 15
# Grade: 4. Comment: The "Project Team Members" section does provide the team roles in the "Team Role" attribute, although it only lists one member with their role. To achieve a perfect score of 5, additional team members could be listed with their corresponding roles to provide more detail and depth.
# Finished grading auto_grading_trainingset/input_files\input8.txt.
#
# Start grading for auto_grading_trainingset/input_files\input9.txt...
# Grade: 5. Comment: The submission provides a clear and concise project name, as well as a detailed description of the purpose and goal of the project. The language is straightforward and easy to understand, giving readers a good sense of what the project aims to accomplish. The mention of "members and families" adds a personal touch, highlighting the human impact of the project.
# Grade: 3. Comment: The submission meets the requirement by including the attribute "Clinic:" with a value of "All Locations", which is sufficient to meet the criteria. However, it could be improved by providing more detail in the Description section beyond just stating the purpose and scope of the project.
# Grade: 5. Comment: The submission provides a clear "Process:" attribute, specifying the implementation of the Unite US platform as part of the project process. Additionally, the description provides context on the purpose of the project, which is to address social and economic needs for members and families, highlighting its relevance to health-related social needs.
# Grade: 3
#
# Comment: The submission provides the necessary information, but it's a brief statement that doesn't meet the criteria for a detailed response. It does mention the TIP 2.0 Process Milestone ("Health related social needs") properly listed under the "TIP 2.0 Process Milestone:" attribute, but lacks further explanation or context.
# Grade: 3
#
# Comment: The "TIP 2.0 Process Milestone" attribute provides some information, specifically mentioning a milestone related to Health-related social needs. However, the description is brief and lacks additional details about what specific steps or activities will be taken to achieve this milestone. A more detailed response would have provided further insight into the process.
# Grade: 3
# Comment: The submission provides a brief summary of the project, but it could be more detailed. It meets the requirement of providing a basic idea of what the project is about, but it doesn't provide much context or information about the specific goals or objectives of the project. A more detailed description would help to give a clearer understanding of the project's purpose and scope.
# Grade: 3
# Comment: The project description does provide some information about the purpose of the project, but it is quite brief and lacks detail. A goal or purpose statement that clearly explains why this project is important and what it aims to achieve would be more effective.
# Grade: 3
# Comment: The submission provides a brief description of the project's purpose, mentioning the importance of addressing social and economic needs for members' overall well-being. However, it could be more detailed by describing what specific results are expected from this project, such as increased referrals to community resources or improved health outcomes due to better social need identification.
# Grade: 5. Comment: The submission provides a detailed and multi-sentence response to the problem summary, effectively describing the social and economic challenges faced by underprivileged families in rural communities served by MIKID. The description highlights the impact of these challenges on families and patients, including unmet needs and limited access to resources. The language is clear and concise, providing a solid foundation for understanding the project's objectives and expected outcomes.
# Grade: 4. Comment: The submission provides a good start in describing the desired outcomes, but it could be more detailed. It mentions specific goals, such as having 15% of families signed up on the platform, but it would be beneficial to elaborate on what this means in terms of concrete results (e.g., number of resources accessed, improved social and economic outcomes). Additionally, the language used is generally straightforward, but some sentences could be rephrased for greater clarity. Overall, a solid effort that could benefit from further elaboration.
# Grade: 4. Comment: The "Benefits:" attribute provides a brief but clear description of the expected benefits of the project, stating that it will provide families with the much-needed and requested resources through the implementation of the Unite US platform. While the response could be more detailed, it meets the requirements by describing one sentence the expected benefit of the project.
# Grade: 3. Comment: The task list provides a good starting point, but it seems to be missing some essential tasks that are crucial to the project's success. For example, there is no mention of testing or quality assurance, which is important for ensuring that the process works as intended. Additionally, the timeline only shows three months, but it's likely that the project will take longer than that to complete. Providing more detail on the scope and duration of the project would be helpful in clarifying the tasks involved.
# Grade: 4. Comment: The submission provides specific task names, descriptions, and completion dates for each task. Each task has a specific month associated with it (Month 1, Month 2, etc.), which meets the criteria of having a specific due date. However, the due dates could be more precise (e.g., Task 1 is to be completed by the end of Month 1) rather than just being associated with a general timeframe. Overall, the submission provides the necessary information and demonstrates a good understanding of task planning and scheduling.
# Grade: 3. Comment: The "In Scope Project Objectives" section provides a brief description of the project's goals, which is good. However, the responses could be more detailed and multi-sentence in nature to better reflect the project's core purpose. As it stands, the submission only provides a few bullet points that do not fully convey the scope of the project.
# Grade: 5. Comment: The submission provides a clear and concise "In Scope" section, listing the objectives that are aligned with the project. Additionally, it includes an "Out of Scope" section that clearly defines what is excluded from the project's scope, making it easy to understand what is included and what is not.
# Grade: 3. Comment: The submission provides a clear distinction between in-scope and out-of-scope project objectives, which meets the requirement. However, the responses could be more detailed and provide explicit connections to key project milestones. A simple listing of objective descriptions without further elaboration or context limits the assessment to a mid-range score.
# Grade: 3. Comment: The "Team Lead:" attribute is partially filled, as the name "Hired SDOH Coordinator" is provided, which suggests that this person will be leading the team. However, it would be more ideal to include a specific name instead of a job title, as it provides clarity and accountability. Overall, the submission meets the requirements but could improve by providing a specific team lead's name.
# Grade: 4. Comment: The submission provides the necessary information for the "Project Champion:" attribute, correctly filling it with a person's name ("Health Information Manager"). The only suggestion would be to provide more context or details about why this individual was chosen as the project champion, but overall, the submission meets the requirements and is well-organized.
# Grade: 3
# Comment: The submission provides the necessary information, specifying the owner by name for the "Process Owner" attribute with "Director of Health". However, it does not provide detailed or multi-sentence responses as per the criteria. A grade of 3 is assigned since the requirements are met, but the response lacks depth.
# Grade: 3
#
# Comment: The submission provides the necessary information for the "Process Manager:" attribute, listing the Process Owner as Director of Health and the Information Process Manager as Health Information Manager. However, it would be beneficial to include a brief description or explanation of what these roles entail and how they will contribute to the project's success.
# Grade: 4. Comment: The submission provides a list of stakeholders with names and attributes, including title, department, organization, which meets the requirements. However, it could be more detailed by providing additional information about each stakeholder's role in the project or their specific interests or concerns.
# Grade: 4. Comment: The submission provides most of the necessary information for the "Stakeholders" section, including title, department, and organization. However, it would be improved by providing more detail about each stakeholder's role in the project or their specific interests or concerns related to the project. Additionally, the Project Team Members section is incomplete as it only lists names with roles but does not provide any additional information.
# Grade: 3. Comment: The submission provides the necessary information for the "Project Team Members" section, including individual names and team roles. However, the names are all listed as "TBD", which means "To Be Determined". While it's understandable that some team members may not be officially assigned at this stage, providing more detail or specific names would make the submission stronger.
# 2024-10-23 13:47:24,508 - INFO - Finished 14 / 15
# 2024-10-23 13:47:24,509 - INFO - Error files:
# 2024-10-23 13:47:24,509 - INFO - ['auto_grading_trainingset/input_files\\input15.txt']
# 2024-10-23 13:47:24,509 - INFO - Exported results to submission_results_prompt_v8_criteria_v2.csv
# Grade: 3. Comment: The "Project Team Members" section provides the necessary information by listing the team members' names and roles, but it does not include detailed, multi-sentence responses as requested in criterion 8. The team roles are listed briefly, such as "Intake specialist- Northern area", which is satisfactory for meeting the requirements, hence the grade of 3.
# Finished grading auto_grading_trainingset/input_files\input9.txt.
#                                            filename AI_Grade  \
# 0    auto_grading_trainingset/input_files\input.txt        5
# 1    auto_grading_trainingset/input_files\input.txt        5
# 2    auto_grading_trainingset/input_files\input.txt        5
# 3    auto_grading_trainingset/input_files\input.txt        5
# 4    auto_grading_trainingset/input_files\input.txt        5
# ..                                              ...      ...
# 19  auto_grading_trainingset/input_files\input9.txt        3
# 20  auto_grading_trainingset/input_files\input9.txt        4
# 21  auto_grading_trainingset/input_files\input9.txt        4
# 22  auto_grading_trainingset/input_files\input9.txt        3
# 23  auto_grading_trainingset/input_files\input9.txt        3
#
#                                               Comment      Section  \
# 0   . Comment: The submission provides a clear and...  Description
# 1   Comment: This submission meets the criteria pe...  Description
# 2   . Comment: This submission meets the requireme...  Description
# 3   Comment: The submission provides a detailed, m...  Description
# 4   . Comment: The submission meets all the requir...  Description
# ..                                                ...          ...
# 19  Comment: The submission provides the necessary...         Team
# 20  . Comment: The submission provides a list of s...         Team
# 21  . Comment: The submission provides most of the...         Team
# 22  . Comment: The submission provides the necessa...         Team
# 23  . Comment: The "Project Team Members" section ...         Team
#
#                                              Criteria
# 0   1. Is the attribute "Project Name:" mentioned ...
# 1   2. Does the file include the attribute "Clinic:"?
# 2   3. Is the attribute "Process:" present in the ...
# 3   4. Is the "TIP 2.0 Process Milestone:" attribu...
# 4   5. Does the "TIP 2.0 Process Milestone:" attri...
# ..                                                ...
# 19  4. Is the "Process Manager:" attribute properl...
# 20  5. Are "Stakeholders" listed with names in the...
# 21  6. Are the "Stakeholders" properly labeled wit...
# 22  7. Does the "Project Team Members" section con...
# 23  8. Does the "Project Team Members" section pro...
#
# [336 rows x 5 columns]

# %% [markdown]
# ## Generate DataFrame of Prompts for All Files in Input Folder

# %%
prompts_list = []

for file_path in files_list:
    try:
        submission = SubmissionGrader(file_path=file_path,
                                grading_prompts=grading_prompts_v5,
                                grading_criterias=criteria_dict_v2)
        prompts_df = submission.get_prompts_for_all_section()
        prompts_list.append(prompts_df)
        print(f"Finished generating prompts for {file_path}")
    except Exception as e:
        print(f"Error processing {file_path}: {e}")

all_prompts_df = pd.concat(prompts_list, axis=0)
all_prompts_df
# Out:
# Generating prompts for auto_grading_trainingset\input_files\input.txt...
# Finished generating prompts for auto_grading_trainingset\input_files\input.txt.
# Finished generating prompts for auto_grading_trainingset\input_files\input.txt
#
# Generating prompts for auto_grading_trainingset\input_files\input10.txt...
# Finished generating prompts for auto_grading_trainingset\input_files\input10.txt.
# Finished generating prompts for auto_grading_trainingset\input_files\input10.txt
#
# Generating prompts for auto_grading_trainingset\input_files\input11.txt...
# Finished generating prompts for auto_grading_trainingset\input_files\input11.txt.
# Finished generating prompts for auto_grading_trainingset\input_files\input11.txt
#
# Generating prompts for auto_grading_trainingset\input_files\input12.txt...
# Finished generating prompts for auto_grading_trainingset\input_files\input12.txt.
# Finished generating prompts for auto_grading_trainingset\input_files\input12.txt
#
# Generating prompts for auto_grading_trainingset\input_files\input14.txt...
# Finished generating prompts for auto_grading_trainingset\input_files\input14.txt.
# Finished generating prompts for auto_grading_trainingset\input_files\input14.txt
#
# Generating prompts for auto_grading_trainingset\input_files\input15.txt...
# Error processing auto_grading_trainingset\input_files\input15.txt: 'Scope'
#
# Generating prompts for auto_grading_trainingset\input_files\input16.txt...
# Finished generating prompts for auto_grading_trainingset\input_files\input16.txt.
# Finished generating prompts for auto_grading_trainingset\input_files\input16.txt
#
# Generating prompts for auto_grading_trainingset\input_files\input2.txt...
# Finished generating prompts for auto_grading_trainingset\input_files\input2.txt.
# Finished generating prompts for auto_grading_trainingset\input_files\input2.txt
#
# Generating prompts for auto_grading_trainingset\input_files\input3.txt...
# Finished generating prompts for auto_grading_trainingset\input_files\input3.txt.
# Finished generating prompts for auto_grading_trainingset\input_files\input3.txt
#
# Generating prompts for auto_grading_trainingset\input_files\input4.txt...
# Finished generating prompts for auto_grading_trainingset\input_files\input4.txt.
# Finished generating prompts for auto_grading_trainingset\input_files\input4.txt
#
# Generating prompts for auto_grading_trainingset\input_files\input5.txt...
# Finished generating prompts for auto_grading_trainingset\input_files\input5.txt.
# Finished generating prompts for auto_grading_trainingset\input_files\input5.txt
#
# Generating prompts for auto_grading_trainingset\input_files\input6.txt...
# Finished generating prompts for auto_grading_trainingset\input_files\input6.txt.
# Finished generating prompts for auto_grading_trainingset\input_files\input6.txt
#
# Generating prompts for auto_grading_trainingset\input_files\input7.txt...
# Finished generating prompts for auto_grading_trainingset\input_files\input7.txt.
# Finished generating prompts for auto_grading_trainingset\input_files\input7.txt
#
# Generating prompts for auto_grading_trainingset\input_files\input8.txt...
# Finished generating prompts for auto_grading_trainingset\input_files\input8.txt.
# Finished generating prompts for auto_grading_trainingset\input_files\input8.txt
#
# Generating prompts for auto_grading_trainingset\input_files\input9.txt...
# Finished generating prompts for auto_grading_trainingset\input_files\input9.txt.
# Finished generating prompts for auto_grading_trainingset\input_files\input9.txt
#                                            filename      Section  \
# 0    auto_grading_trainingset\input_files\input.txt  Description
# 1    auto_grading_trainingset\input_files\input.txt  Description
# 2    auto_grading_trainingset\input_files\input.txt  Description
# 3    auto_grading_trainingset\input_files\input.txt  Description
# 4    auto_grading_trainingset\input_files\input.txt  Description
# ..                                              ...          ...
# 19  auto_grading_trainingset\input_files\input9.txt         Team
# 20  auto_grading_trainingset\input_files\input9.txt         Team
# 21  auto_grading_trainingset\input_files\input9.txt         Team
# 22  auto_grading_trainingset\input_files\input9.txt         Team
# 23  auto_grading_trainingset\input_files\input9.txt         Team
#
#                                              Criteria  \
# 0   1. Does the name of the "Project Name:" attrib...
# 1   2. Does the name of the "Clinic:" attribute sp...
# 2   3. Does the name of the "Process:" attribute s...
# 3   4. Does the name of the "TIP 2.0 Process Miles...
# 4   5. Does the name of the "TIP 2.0 Process Miles...
# ..                                                ...
# 19  4. Does the value of the "Process Manager:" at...
# 20  5. Does the value of the "Stakeholders" "stake...
# 21  6. Do the "Stakeholders" contain values for th...
# 22  7. Does the value of the "Project Team Members...
# 23  8. Do the "Project Team Members" contain role ...
#
#                                                Prompt
# 0   \nYou are grading a project Description. This ...
# 1   \nYou are grading a project Description. This ...
# 2   \nYou are grading a project Description. This ...
# 3   \nYou are grading a project Description. This ...
# 4   \nYou are grading a project Description. This ...
# ..                                                ...
# 19  \nYou are grading a project Team. This is the ...
# 20  \nYou are grading a project Team. This is the ...
# 21  \nYou are grading a project Team. This is the ...
# 22  \nYou are grading a project Team. This is the ...
# 23  \nYou are grading a project Team. This is the ...
#
# [336 rows x 4 columns]

# %%
all_prompts_df.to_csv("all_prompts_df.csv", index=False)

# %% [markdown]
# # Tkinter UI

# %%
from tkinter import *
import tkinter as tk
from tkinter import filedialog
from tkinter import ttk
import re
import requests
import threading
import os
import pandas as pd

class Application(Frame):

    def __init__(self, master=None, Frame=None, criteria="", criteria_dict={},grading_prompts={}):
        self.criteria = criteria
        self.criteria_dict = criteria_dict
        self.grading_prompts = grading_prompts
        self.submission = ""
        self.submissions = []
        self.grade_csv = []
        self.prompt = ""
        Frame.__init__(self, master)
        super(Application,self).__init__()
        self.grid(column = 5,row = 20,padx = 50,pady = 50)
        self.createWidgets()

    def getUpdateData(self,  event):
        self.CriteriaCombo['values'] = self.criteria_dict[self.SectionCombo.get()]
        self.CriteriaCombo.current()

    def parseTextFile(self, text):
        pattern = r'(' + '|'.join(re.escape(name) for name in self.criteria_dict.keys()) + '):'

        # Find all the section headers and split the text accordingly
        sections = re.split(pattern, text)

        # The first element in sections is either empty or non-useful text before the first header
        sections = sections[1:]  # Skip the first element as it would be empty or non-section text

        # Creating a dictionary to store the section names and their corresponding content
        section_dict = {}

        # Iterate over the list in pairs: section name and its corresponding text
        for i in range(0, len(sections), 2):
            section_name = sections[i].strip()  # Section name (e.g., 'Description')
            section_content = sections[i+1].strip()  # Corresponding content

            if section_name in self.criteria_dict.keys():  # Only add the section if it's in the predefined list
                section_dict[section_name] = section_content
        
        return section_dict

    def getFileContent(self):
        file_path = filedialog.askopenfilename(title="Select a file", filetypes=[("Text files", "*.txt"), ("All files", "*.*")])
        if file_path:
            # Process the selected file (you can replace this with your own logic)
            # print("Selected file:", file_path)
            s = open(file_path, 'r').read()
            content_dict = self.parseTextFile(s)
            # print("Content: ", content_dict[self.SectionCombo.get()])
            self.submission = content_dict[self.SectionCombo.get()]
            self.status.config(text="imported " + file_path)

    def getFolderContent(self):
        folder_path = filedialog.askdirectory()
        if folder_path:
            # Process the selected file (you can replace this with your own logic)
            # List all items in the folder
            all_items = os.listdir(folder_path)
            self.status.config(text="imported " + folder_path)
            # Filter and return only files (not directories)
            files = [os.path.join(folder_path, f) for f in all_items if os.path.isfile(os.path.join(folder_path, f))]
            print("All files: ", all_items)
            self.submissions = files
            self.status.config(text="imported " + folder_path)
            return files
    def setCriteria(self):
        self.criteria = self.CriteriaCombo.get()

    def generatePrompt(self, prompt_submission):
        print("Section: ", self.SectionCombo.get())
        print("criteria: ", self.CriteriaCombo.get())
        prompt = grading_prompts[self.SectionCombo.get()].format(criteria=self.CriteriaCombo.get()) + prompt_submission
        # print(prompt)
        self.prompt = prompt

    def call_api(self):
        print("calling api")
        url = "http://localhost:11434/api/chat"
        # The JSON data that would be sent in the POST request
        data = {
            "model": "llama3",
            "messages": [
                { "role": "user", "content": self.prompt }
            ],
            "stream": False
        }
        # Send the POST request
        response = requests.post(url, json=data)

        # Check if the request was successful
        if response.status_code == 200:
            # Return the JSON response
            print(response.json()["message"]["content"])
            pattern = r"Grade:\s*([\d\.]+)"
            match = re.search(pattern, response.json()["message"]["content"])
            return match.group(1)
            
        else:
            print(f"Error: {response.status_code}, {response.text}")

    def getComment(self):
        self.generatePrompt(self.submission)
        self.status.config(text="Running...")
        
        def api_thread():
            response = self.call_api()
            self.status.config(text="Grade: " + response)
            self.submission = ""
        thread = threading.Thread(target=api_thread)
        thread.start()
        

    def getCommentForFolder(self, path, content,completed):
        print("\nGetting comment for file: ",path)
        self.generatePrompt(content)
        self.status.config(text="Running...")
        
        def api_thread():
            response = self.call_api()
            self.grade_csv.append([path,response,self.SectionCombo.get(),self.CriteriaCombo.get()])
            print("current grade_csv: ",self.grade_csv)
            self.status.config(text="Running...Completed" + str(completed) + "/" + str(len(self.submissions)))
            if len(self.grade_csv) == len(self.submissions):
                print("\nSelf.grade_csv: ",len(self.grade_csv))
                print("self.submissions: ",len(self.submissions))
                filename = "grade_result_" + self.SectionCombo.get() + "_" + str(self.criteria_dict[self.SectionCombo.get()].index(self.CriteriaCombo.get()))
                pd.DataFrame(self.grade_csv,columns=["File","Grade","Section","Criteria"]).to_csv(filename+".csv")
                self.status.config(text="Exported csv file to " + filename+".csv")
                self.submissions = []
                self.grade_csv = []
        thread = threading.Thread(target=api_thread)
        thread.start()
        
    def getGradeResults(self):
        print("Number of files: ",len(self.submissions))
        for i in range(len(self.submissions)):
            file_path = self.submissions[i]
            print("file path: ", file_path)
            s = open(file_path, 'r').read()
            file_content_dict = self.parseTextFile(s)
            print("File content: ",file_content_dict)
            file_content = file_content_dict[self.SectionCombo.get()]
            self.getCommentForFolder(file_path,file_content,i)

    def getAIfeedback(self):
        print("self.submissions:", self.submissions)
        if len(self.submissions):
            print("Grade whole folder")
            self.getGradeResults()
        else:
            self.getComment()

    def createWidgets(self):
        Label(text = 'Section:').grid(row = 1,column = 1,padx = 10)
        Label(text = 'Criteria:').grid(row = 2,column = 1,padx = 10)
        Label(text = 'Import File:').grid(row = 3,column = 1,padx = 10)
        # Criteria list
        self.CriteriaCombo = ttk.Combobox( width = 15)
        self.CriteriaCombo.grid(row = 2,column = 2,pady = 25,padx = 10)
        self.CriteriaCombo.bind('<<ComboboxSelected>>', self.setCriteria())

        # Section list
        self.SectionCombo = ttk.Combobox(width = 15,  values = list(criteria_dict.keys()))
        self.SectionCombo.bind('<<ComboboxSelected>>', self.getUpdateData)
        self.SectionCombo.grid(row = 1,column = 2,padx = 10,pady = 25)

        # Import File button
        self.importButton = ttk.Button(text="Import 1 File", command=self.getFileContent)
        self.importButton.grid(column=2,row=3)

        # Import Folder buttonA
        self.importButton = ttk.Button(text="Import whole Folder", command=self.getFolderContent)
        self.importButton.grid(column=3,row=3)

        # # Generate Prompt button
        # self.generatePromptButton = ttk.Button(text="Generate Prompt", command=self.generatePrompt)
        # self.generatePromptButton.grid(column=2,row=4)

        # Get feedback from AI model
        self.getCommentButton = ttk.Button(text="Get feedback from AI model", command=self.getAIfeedback)
        self.getCommentButton.grid(column=2,row=5)

        # Status
        self.status = Label(text="")
        self.status.grid(column=2, row=6)
app = Application()
app.master.title('Generate Prompts for Llama3')
app.criteria = ""
app.criteria_dict = criteria_dict
app.grading_prompts = grading_prompts
app.mainloop()

# %% [markdown]
# # Autogenerate grades for different prompt with maximum grade for each section (Park Version)

# %% [markdown]
# # Covert txt files to docx

# %%
from docx import Document
import re
import os

path = 'auto_grading_trainingset/input_files'
direct = os.listdir(path)

for i in direct:
    document = Document()
    document.add_heading(i, 0)
    myfile = open( path+"/"+i).read()
    myfile = re.sub(r'[^\x00-\x7F]+|\x0c',' ', myfile) # remove all non-XML-compatible characters
    p = document.add_paragraph(myfile)
    document.save('auto_grading_trainingset/input_files_docx/'+i+'.docx')

# %% [markdown]
# ## Copy the charter template 14 times

# %%
import shutil
import os

# %%
# Define the source file
source_file = 'auto_grading_trainingset/input_files_docx/template.docx'

# Loop through the range from 1 to 16
for i in range(1, 17):
    # Construct the destination file name
    destination_file = f'auto_grading_trainingset/input_files_docx/input{i}.docx'
    
    # Copy the source file to the destination file
    shutil.copy(source_file, destination_file)

# %% [markdown]
# # Automate for Park's promt

# %%
from langchain import PromptTemplate
from langchain_core.prompts.few_shot import FewShotPromptTemplate
import yaml
import pandas as pd
import numpy as np
import os
from beeprint import pp
import re
import requests
import sys

# %%
def generate_prompt(rubric: dict, part_name: str):
   if part_name not in rubric:
      return f"No rubric found for {part_name}."

   prompt = """
   You are an evaluator. Below is a rubric for evaluating various parts of a project report. Please evaluate each section based on the specific criteria provided for each section.
   """

   for criterion in rubric[part_name]['criteria']:
      prompt += f"- {criterion['name']} (Score Range: {criterion['grade_range']})\n"

   prompt += f"""
   Instructions:
   1. Assign a score based on the criteria and provided grade range.
   2. For **each score assigned**, provide a **clear and detailed explanation** that justifies the score, including references to specific aspects of the project report that led to the score.
      - If the score is low, explain what was missing or insufficient.
      - If the score is high, explain what was well-done or exceeded expectations.
      - Focus only on the evaluation of '{part_name}' as a whole.
      - Do not create or refer to any sub-sections under '{part_name}'.
   3. Ensure that **every question** under '{part_name}' is evaluated. Do not skip or omit any questions, even if the response is minimal.
   4. The explanation should focus on **how well the report meets the criteria** outlined for that section.
   5. The 'Total Score' should be the sum of all individual question scores, and 'Overall Description' should summarize the evaluation.
   6. Ensure the JSON is well-formed, properly indented, and does not contain any syntax errors.
      - Example format:
         {{
               "{part_name}": {{
                  "Question 1": {{
                     "score": "",
                     "explanation": ""
                  }},
                  "Question 2": {{
                     "score": "",
                     "explanation": ""
                  }},
                  ...
                  "Total Score": "",
                  "Overall Description": ""
               }}
         }}
   7. Respond only with the JSON object. Do not include any explanations outside the JSON.
   """
   return prompt

# %%
# Load rubric from the YAML file
def load_rubric(filename: str):
    with open(filename, 'r') as file:
        rubric = yaml.safe_load(file)
    return rubric

# %%
rubric = load_rubric('rubric_files/criteria_dict.yaml')
rubric
# Out:
# {'ProcessMilestone': {'criteria': [{'name': "Does the value of the 'Project Name:' attribute exist in the file?",
#     'grade_range': '0-2'},
#    {'name': "Does the value of the 'Clinic:' attribute exist in the file?",
#     'grade_range': '0-2'},
#    {'name': "Does the value of the 'Process:' attribute exist in the file?",
#     'grade_range': '0-2'},
#    {'name': "Does the value of the 'TIP 2.0 Process Milestone:' attribute exist in the file?",
#     'grade_range': '0-2'},
#    {'name': "Does the value of the 'TIP 2.0 Process Milestone:' attribute include process milestone details?",
#     'grade_range': '0-2'}]},
#  'ProjectDescription': {'criteria': [{'name': "Does the value of the 'Project Description / Purpose' attribute include a brief description of the project?",
#     'grade_range': '0-7'},
#    {'name': "Does the value of the 'Project Description / Purpose' attribute include detailed aims or purpose of the project?",
#     'grade_range': '0-7'},
#    {'name': "Does the value of the 'Project Description / Purpose' attribute include detailed expected results from the project?",
#     'grade_range': '0-6'}]},
#  'ProjectOverview': {'criteria': [{'name': "Does the value of the 'Problem Summary:' attribute include a detailed and logical problem statement?",
#     'grade_range': '0-9'},
#    {'name': "Does the value of the 'Desired Outcome(s):' attribute include a detailed and logical description?",
#     'grade_range': '0-8'},
#    {'name': "Does the value of the 'Benefits:' attribute include a detailed and logical expected benefits?",
#     'grade_range': '0-8'}]},
#  'Timeline': {'criteria': [{'name': 'Does the value of the each task list key tasks?',
#     'grade_range': '0-10'},
#    {'name': 'Does the value of the each task contain a specific planned completion due date?',
#     'grade_range': '0-5'}]},
#  'ProjectScope': {'criteria': [{'name': "Does the value of the 'In Scope Project Objectives' attribute include an aligned objectives with the project purpose?",
#     'grade_range': '0-8'},
#    {'name': "Does the value of the 'Out of Scope Project Objectives or Activities' attribute include an aligned objectives with the project purpose?",
#     'grade_range': '0-7'}]},
#  'ProjectTeam': {'criteria': [{'name': "Does the value of the 'Team Lead:' attribute contain an individual's name?",
#     'grade_range': '0-2'},
#    {'name': "Does the value of the 'Project Champion:' attribute contain an individual's name?",
#     'grade_range': '0-2'},
#    {'name': "Does the value of the 'Process Owner:' attribute contain an individual's name?",
#     'grade_range': '0-2'},
#    {'name': "Does the value of the 'Process Manager:' attribute contain an individual's name?",
#     'grade_range': '0-2'},
#    {'name': "Does the value of the 'Stakeholders' stakeholder attribute contain an individual's name?",
#     'grade_range': '0-2'},
#    {'name': "Does the 'Stakeholders' contain values for the attributes: stakeholder, title, department, and organization?",
#     'grade_range': '0-2'},
#    {'name': "Does the value of the 'Project Team Members' Name attribute contain an individual's name?",
#     'grade_range': '0-2'},
#    {'name': "Do the 'Project Team Members' contain role values for the 'Team role' attribute?",
#     'grade_range': '0-1'}]}}

# %%
print(generate_prompt(rubric, 'ProcessMilestone'))
# Out:
#    You are an evaluator. Below is a rubric for evaluating various parts of a project report. Please evaluate each section based on the specific criteria provided for each section.
#    - Does the value of the 'Project Name:' attribute exist in the file? (Score Range: 0-2)
# - Does the value of the 'Clinic:' attribute exist in the file? (Score Range: 0-2)
# - Does the value of the 'Process:' attribute exist in the file? (Score Range: 0-2)
# - Does the value of the 'TIP 2.0 Process Milestone:' attribute exist in the file? (Score Range: 0-2)
# - Does the value of the 'TIP 2.0 Process Milestone:' attribute include process milestone details? (Score Range: 0-2)
#
#    Instructions:
#    1. Assign a score based on the criteria and provided grade range.
#    2. For **each score assigned**, provide a **clear and detailed explanation** that justifies the score, including references to specific aspects of the project report that led to the score.
#       - If the score is low, explain what was missing or insufficient.
#       - If the score is high, explain what was well-done or exceeded expectations.
#       - Focus only on the evaluation of 'ProcessMilestone' as a whole.
#       - Do not create or refer to any sub-sections under 'ProcessMilestone'.
#    3. Ensure that **every question** under 'ProcessMilestone' is evaluated. Do not skip or omit any questions, even if the response is minimal.
#    4. The explanation should focus on **how well the report meets the criteria** outlined for that section.
#    5. The 'Total Score' should be the sum of all individual question scores, and 'Overall Description' should summarize the evaluation.
#    6. Ensure the JSON is well-formed, properly indented, and does not contain any syntax errors.
#       - Example format:
#          {
#                "ProcessMilestone": {
#                   "Question 1": {
#                      "score": "",
#                      "explanation": ""
#                   },
#                   "Question 2": {
#                      "score": "",
#                      "explanation": ""
#                   },
#                   ...
#                   "Total Score": "",
#                   "Overall Description": ""
#                }
#          }
#    7. Respond only with the JSON object. Do not include any explanations outside the JSON.
